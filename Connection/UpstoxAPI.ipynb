# %%
pip install upstox
# Out:
# Collecting upstox
#   Downloading upstox-2.0.1-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: future in c:\programdata\anaconda3\lib\site-packages (from upstox) (0.18.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from upstox) (2.24.0)
# Collecting websocket-client
#   Downloading websocket_client-1.0.0-py2.py3-none-any.whl (68 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->upstox) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->upstox) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->upstox) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->upstox) (2020.6.20)
# Installing collected packages: websocket-client, upstox
# Successfully installed upstox-2.0.1 websocket-client-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from upstox_api.api import *

# %%
s = Session ('ad6nG8e7bi802QfECfsdk3CTEXZrQv6y1pJ6ZPWy')
s.set_redirect_uri ('https://upstox.com')
s.set_api_secret ('u5nq458pgc')

# %%
print (s.get_login_url())
# Out:
# https://api.upstox.com/index/dialog/authorize?apiKey=ad6nG8e7bi802QfECfsdk3CTEXZrQv6y1pJ6ZPWy&redirect_uri=https%3A%2F%2Fupstox.com&response_type=code

# %%
s.set_code ('8617ba794ad0df0d0eba79b45e3ffa2a22f2339e')

# %%
access_token = s.retrieve_access_token()
print ('Received access_token: %s' % access_token)
# Out:
# Received access_token: {'access_token': '5c9fad69012ace41aff83251af796a983a41e2a8', 'expires_in': 86400000, 'user_details': {'name': 'VINAY DAYAL DADU', 'phone': '7702079652', 'email': 'vinaydadu@gmail.com', 'client_id': 'KF6449'}, 'token_type': 'Bearer'}

# %%
u = Upstox('ad6nG8e7bi802QfECfsdk3CTEXZrQv6y1pJ6ZPWy','5c9fad69012ace41aff83251af796a983a41e2a8')

# %%
print (u.get_balance()) # get balance / margin limits
print (u.get_profile()) # get profile
print (u.get_holdings()) # get holdings
print (u.get_positions()) # get positions
# Out:
# {'equity': {'used_margin': 0, 'payin_amount': 0, 'span_margin': 0, 'adhoc_margin': 0, 'notional_cash': 0, 'ledger_balance': 55979.73, 'exposure_margin': 0, 'mutual_fund_amount': 0, 'payout_amount': 0, 'available_margin': 55979.73}, 'commodity': {'used_margin': 0, 'payin_amount': 0, 'span_margin': 0, 'adhoc_margin': 0, 'notional_cash': 0, 'ledger_balance': 0, 'exposure_margin': 0, 'mutual_fund_amount': 0, 'payout_amount': 0, 'available_margin': 0}}
# {'client_id': 'KF6449', 'name': 'VINAY DAYAL DADU', 'email': 'vinaydadu@gmail.com', 'phone': '7702079652', 'is_active': True, 'exchanges_enabled': ['BCD_FO', 'BSE_EQ', 'MCX_FO', 'NCD_FO', 'NSE_EQ', 'NSE_FO', 'NSE_INDEX', 'BSE_INDEX'], 'products_enabled': [], 'bank_name': 'INDUSIND BANK LTD', 'bank_account': '152569702077', 'bank_name2': 'ICICI BANK LTD', 'bank_account2': '007501529886'}
# [{'avg_price': '23.35', 'cnc_used_quantity': 0, 'collateral_qty': 0, 'collateral_type': 'WC', 'company_name': 'CPSE ETF', 'haircut': 14.000000000000002, 'isin': 'INF457M01133', 'product': 'D', 'quantity': 1, 'symbol': 'CPSEETF', 'instrument': [{'exchange': 'NSE_EQ', 'symbol': 'CPSEETF', 'token': 2328, 'series': 'EQ'}, {'exchange': 'BSE_EQ', 'symbol': 'CPSEETF', 'token': 538057}]}]
# []

# %%
u.get_master_contract('NSE_FO') # get contracts for NSE FO
u.get_master_contract('NSE_EQ') # get contracts for NSE EQ
# Out:
# OrderedDict([(6833,
#               Instrument(exchange='NSE_EQ', token=6833, parent_token=None, symbol='1018gs2026', name='GOI LOAN 10.18% 2026', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020010081')),
#              (6819,
#               Instrument(exchange='NSE_EQ', token=6819, parent_token=None, symbol='1025gs2021', name='GOI LOAN 10.25% 2021', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020010040')),
#              (1776,
#               Instrument(exchange='NSE_EQ', token=1776, parent_token=None, symbol='182d010721', name='GOI TBILL 182D-01/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y397')),
#              (2593,
#               Instrument(exchange='NSE_EQ', token=2593, parent_token=None, symbol='182d020921', name='GOI TBILL 182D-02/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y488')),
#              (1411,
#               Instrument(exchange='NSE_EQ', token=1411, parent_token=None, symbol='182d030621', name='GOI TBILL 182D-03/06/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y348')),
#              (3397,
#               Instrument(exchange='NSE_EQ', token=3397, parent_token=None, symbol='182d041121', name='GOI TBILL 182D-04/11/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Y056')),
#              (2100,
#               Instrument(exchange='NSE_EQ', token=2100, parent_token=None, symbol='182d050821', name='GOI TBILL 182D-05/08/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y447')),
#              (3185,
#               Instrument(exchange='NSE_EQ', token=3185, parent_token=None, symbol='182d071021', name='GOI TBILL 182D-07/10/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Y015')),
#              (1875,
#               Instrument(exchange='NSE_EQ', token=1875, parent_token=None, symbol='182d080721', name='GOI TBILL 182D-08/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y405')),
#              (1459,
#               Instrument(exchange='NSE_EQ', token=1459, parent_token=None, symbol='182d100621', name='GOI TBILL 182D-10/06/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y355')),
#              (2703,
#               Instrument(exchange='NSE_EQ', token=2703, parent_token=None, symbol='182d100921', name='GOI TBILL 182D-10/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y496')),
#              (2164,
#               Instrument(exchange='NSE_EQ', token=2164, parent_token=None, symbol='182d120821', name='GOI TBILL 182D-12/08/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y454')),
#              (3526,
#               Instrument(exchange='NSE_EQ', token=3526, parent_token=None, symbol='182d121121', name='GOI TBILL 182D-12/11/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Y064')),
#              (3217,
#               Instrument(exchange='NSE_EQ', token=3217, parent_token=None, symbol='182d141021', name='GOI TBILL 182D-14/10/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Y023')),
#              (1914,
#               Instrument(exchange='NSE_EQ', token=1914, parent_token=None, symbol='182d150721', name='GOI TBILL 182D-15/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y413')),
#              (2777,
#               Instrument(exchange='NSE_EQ', token=2777, parent_token=None, symbol='182d160921', name='GOI TBILL 182D-16/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y504')),
#              (1538,
#               Instrument(exchange='NSE_EQ', token=1538, parent_token=None, symbol='182d170621', name='GOI TBILL 182D-17/06/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y371')),
#              (3583,
#               Instrument(exchange='NSE_EQ', token=3583, parent_token=None, symbol='182d181121', name='GOI TBILL 182D-18/11/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Y072')),
#              (2269,
#               Instrument(exchange='NSE_EQ', token=2269, parent_token=None, symbol='182d190821', name='GOI TBILL 182D-19/08/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y462')),
#              (3270,
#               Instrument(exchange='NSE_EQ', token=3270, parent_token=None, symbol='182d211021', name='GOI TBILL 182D-21/10/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Y031')),
#              (1965,
#               Instrument(exchange='NSE_EQ', token=1965, parent_token=None, symbol='182d220721', name='GOI TBILL 182D-22/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y421')),
#              (2949,
#               Instrument(exchange='NSE_EQ', token=2949, parent_token=None, symbol='182d230921', name='GOI TBILL 182D-23/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y512')),
#              (1641,
#               Instrument(exchange='NSE_EQ', token=1641, parent_token=None, symbol='182d240621', name='GOI TBILL 182D-24/06/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y389')),
#              (2422,
#               Instrument(exchange='NSE_EQ', token=2422, parent_token=None, symbol='182d260821', name='GOI TBILL 182D-26/08/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y470')),
#              (3311,
#               Instrument(exchange='NSE_EQ', token=3311, parent_token=None, symbol='182d281021', name='GOI TBILL 182D-28/10/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Y049')),
#              (2026,
#               Instrument(exchange='NSE_EQ', token=2026, parent_token=None, symbol='182d290721', name='GOI TBILL 182D-29/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y439')),
#              (3092,
#               Instrument(exchange='NSE_EQ', token=3092, parent_token=None, symbol='182d290921', name='GOI TBILL 182D-29/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Y520')),
#              (16921,
#               Instrument(exchange='NSE_EQ', token=16921, parent_token=None, symbol='20microns', name='20 MICRONS LTD', closing_price=62.8, expiry=None, strike_price=None, tick_size=5.0, lot_size=1, instrument_type='EQUITY', isin='INE144J01027')),
#              (4,
#               Instrument(exchange='NSE_EQ', token=4, parent_token=None, symbol='21stcenmgm', name='21ST CENTURY MGMT SERVICE', closing_price=14.85, expiry=None, strike_price=None, tick_size=5.0, lot_size=1, instrument_type='EQUITY', isin='INE253B01015')),
#              (20004,
#               Instrument(exchange='NSE_EQ', token=20004, parent_token=None, symbol='364d010721', name='GOI T BILL 364D-01/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z139')),
#              (22445,
#               Instrument(exchange='NSE_EQ', token=22445, parent_token=None, symbol='364d020921', name='GOI TBILL 364D-02/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z220')),
#              (1413,
#               Instrument(exchange='NSE_EQ', token=1413, parent_token=None, symbol='364d021221', name='GOI TBILL 364D-02/12/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z345')),
#              (2104,
#               Instrument(exchange='NSE_EQ', token=2104, parent_token=None, symbol='364d030222', name='GOI TBILL 364D-03/02/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z444')),
#              (2596,
#               Instrument(exchange='NSE_EQ', token=2596, parent_token=None, symbol='364d030322', name='GOI TBILL 364D-03/03/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z485')),
#              (19570,
#               Instrument(exchange='NSE_EQ', token=19570, parent_token=None, symbol='364d030621', name='GOI T BILL 364D-03/06/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z097')),
#              (1027,
#               Instrument(exchange='NSE_EQ', token=1027, parent_token=None, symbol='364d041121', name='GOI TBILL 364D-04/11/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z303')),
#              (3400,
#               Instrument(exchange='NSE_EQ', token=3400, parent_token=None, symbol='364d050522', name='GOI TBILL 364D-05/05/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Z053')),
#              (22307,
#               Instrument(exchange='NSE_EQ', token=22307, parent_token=None, symbol='364d050821', name='GOI TBILL 364D-05/08/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z188')),
#              (1876,
#               Instrument(exchange='NSE_EQ', token=1876, parent_token=None, symbol='364d060122', name='GOI TBILL 364D-06/01/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z402')),
#              (3187,
#               Instrument(exchange='NSE_EQ', token=3187, parent_token=None, symbol='364d070422', name='GOI TBILL 364D-07/04/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Z012')),
#              (414,
#               Instrument(exchange='NSE_EQ', token=414, parent_token=None, symbol='364d071021', name='GOI TBILL 364D-07/10/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z261')),
#              (19989,
#               Instrument(exchange='NSE_EQ', token=19989, parent_token=None, symbol='364d080721', name='GOI T BILL 364D-08/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z147')),
#              (6,
#               Instrument(exchange='NSE_EQ', token=6, parent_token=None, symbol='364d090921', name='GOI TBILL 364D-09/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z238')),
#              (1460,
#               Instrument(exchange='NSE_EQ', token=1460, parent_token=None, symbol='364d091221', name='GOI TBILL 364D-09/12/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z352')),
#              (2167,
#               Instrument(exchange='NSE_EQ', token=2167, parent_token=None, symbol='364d100222', name='GOI TBILL 364D-10/02/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z451')),
#              (19836,
#               Instrument(exchange='NSE_EQ', token=19836, parent_token=None, symbol='364d100621', name='GOI T BILL 364D-10/06/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z105')),
#              (2706,
#               Instrument(exchange='NSE_EQ', token=2706, parent_token=None, symbol='364d110322', name='GOI TBILL 364D-11/03/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z493')),
#              (1107,
#               Instrument(exchange='NSE_EQ', token=1107, parent_token=None, symbol='364d111121', name='GOI TBILL 364D-11/11/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z311')),
#              (22330,
#               Instrument(exchange='NSE_EQ', token=22330, parent_token=None, symbol='364d120821', name='GOI TBILL 364D-12/08/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z196')),
#              (1917,
#               Instrument(exchange='NSE_EQ', token=1917, parent_token=None, symbol='364d130122', name='GOI TBILL 364D-13/01/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z410')),
#              (3527,
#               Instrument(exchange='NSE_EQ', token=3527, parent_token=None, symbol='364d130522', name='GOI TBILL 364D-13/05/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Z061')),
#              (3211,
#               Instrument(exchange='NSE_EQ', token=3211, parent_token=None, symbol='364d140422', name='GOI TBILL 364D-14/04/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Z020')),
#              (636,
#               Instrument(exchange='NSE_EQ', token=636, parent_token=None, symbol='364d141021', name='GOI TBILL 364D-14/10/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z279')),
#              (20012,
#               Instrument(exchange='NSE_EQ', token=20012, parent_token=None, symbol='364d150721', name='GOI T BILL 364D-15/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z154')),
#              (102,
#               Instrument(exchange='NSE_EQ', token=102, parent_token=None, symbol='364d160921', name='GOI TBILL 364D-16/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z246')),
#              (1544,
#               Instrument(exchange='NSE_EQ', token=1544, parent_token=None, symbol='364d161221', name='GOI TBILL 364D-16/12/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z378')),
#              (2274,
#               Instrument(exchange='NSE_EQ', token=2274, parent_token=None, symbol='364d170222', name='GOI TBILL 364D-17/02/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z469')),
#              (2780,
#               Instrument(exchange='NSE_EQ', token=2780, parent_token=None, symbol='364d170322', name='GOI TBILL 364D-17/03/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z501')),
#              (19840,
#               Instrument(exchange='NSE_EQ', token=19840, parent_token=None, symbol='364d170621', name='GOI T BILL 364D-17/06/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z113')),
#              (1182,
#               Instrument(exchange='NSE_EQ', token=1182, parent_token=None, symbol='364d181121', name='GOI TBILL 364D-18/11/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z329')),
#              (3584,
#               Instrument(exchange='NSE_EQ', token=3584, parent_token=None, symbol='364d190522', name='GOI TBILL 364D-19/05/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Z079')),
#              (22384,
#               Instrument(exchange='NSE_EQ', token=22384, parent_token=None, symbol='364d190821', name='GOI TBILL 364D-19/08/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z204')),
#              (1968,
#               Instrument(exchange='NSE_EQ', token=1968, parent_token=None, symbol='364d200122', name='GOI TBILL 364D-20/01/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z428')),
#              (3274,
#               Instrument(exchange='NSE_EQ', token=3274, parent_token=None, symbol='364d210422', name='GOI TBILL 364D-21/04/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Z038')),
#              (790,
#               Instrument(exchange='NSE_EQ', token=790, parent_token=None, symbol='364d211021', name='GOI TBILL 364D-21/10/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z287')),
#              (20015,
#               Instrument(exchange='NSE_EQ', token=20015, parent_token=None, symbol='364d220721', name='GOI T BILL 364D-22/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z162')),
#              (194,
#               Instrument(exchange='NSE_EQ', token=194, parent_token=None, symbol='364d230921', name='GOI TBILL 364D-23/09/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z253')),
#              (1643,
#               Instrument(exchange='NSE_EQ', token=1643, parent_token=None, symbol='364d231221', name='GOI TBILL 364D-23/12/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z386')),
#              (2428,
#               Instrument(exchange='NSE_EQ', token=2428, parent_token=None, symbol='364d240222', name='GOI TBILL 364D-24/02/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z477')),
#              (2952,
#               Instrument(exchange='NSE_EQ', token=2952, parent_token=None, symbol='364d240322', name='GOI TBILL 364D-24/03/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z519')),
#              (19982,
#               Instrument(exchange='NSE_EQ', token=19982, parent_token=None, symbol='364d240621', name='GOI T BILL 364D-24/06/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z121')),
#              (1269,
#               Instrument(exchange='NSE_EQ', token=1269, parent_token=None, symbol='364d251121', name='GOI TBILL 364D-25/11/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z337')),
#              (22402,
#               Instrument(exchange='NSE_EQ', token=22402, parent_token=None, symbol='364d260821', name='GOI TBILL 364D-26/08/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z212')),
#              (2027,
#               Instrument(exchange='NSE_EQ', token=2027, parent_token=None, symbol='364d270122', name='GOI TBILL 364D-27/01/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z436')),
#              (3313,
#               Instrument(exchange='NSE_EQ', token=3313, parent_token=None, symbol='364d280422', name='GOI TBILL 364D-28/04/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002021Z046')),
#              (891,
#               Instrument(exchange='NSE_EQ', token=891, parent_token=None, symbol='364d281021', name='GOI TBILL 364D-28/10/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z295')),
#              (22274,
#               Instrument(exchange='NSE_EQ', token=22274, parent_token=None, symbol='364d290721', name='GOI TBILL 364D-29/07/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z170')),
#              (3094,
#               Instrument(exchange='NSE_EQ', token=3094, parent_token=None, symbol='364d300322', name='GOI TBILL 364D-30/03/22', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z527')),
#              (1779,
#               Instrument(exchange='NSE_EQ', token=1779, parent_token=None, symbol='364d301221', name='GOI TBILL 364D-30/12/21', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN002020Z394')),
#              (1051,
#               Instrument(exchange='NSE_EQ', token=1051, parent_token=None, symbol='396gs2022', name='GOI LOAN  3.96% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020200260')),
#              (11774,
#               Instrument(exchange='NSE_EQ', token=11774, parent_token=None, symbol='3iinfotech', name='3I INFOTECH LTD.', closing_price=8.9, expiry=None, strike_price=None, tick_size=5.0, lot_size=1, instrument_type='EQUITY', isin='INE748C01020')),
#              (474,
#               Instrument(exchange='NSE_EQ', token=474, parent_token=None, symbol='3mindia', name='3M INDIA LIMITED', closing_price=26092.7, expiry=None, strike_price=None, tick_size=5.0, lot_size=1, instrument_type='EQUITY', isin='INE470A01017')),
#              (2595,
#               Instrument(exchange='NSE_EQ', token=2595, parent_token=None, symbol='3pland', name='3P LAND HOLDINGS LIMITED', closing_price=13.8, expiry=None, strike_price=None, tick_size=5.0, lot_size=1, instrument_type='EQUITY', isin='INE105C01023')),
#              (5621,
#               Instrument(exchange='NSE_EQ', token=5621, parent_token=None, symbol='3rdrock', name='3RD ROCK MULTIMEDIA LTD', closing_price=None, expiry=None, strike_price=None, tick_size=5.0, lot_size=5200, instrument_type='EQUITY', isin='INE768P01012')),
#              (970,
#               Instrument(exchange='NSE_EQ', token=970, parent_token=None, symbol='415kl22', name='SDL KL 4.15% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200217')),
#              (3529,
#               Instrument(exchange='NSE_EQ', token=3529, parent_token=None, symbol='426gs2023', name='GOI LOAN  4.26% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020210046')),
#              (21931,
#               Instrument(exchange='NSE_EQ', token=21931, parent_token=None, symbol='439mh23', name='SDL MH 4.39% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2220200108')),
#              (21938,
#               Instrument(exchange='NSE_EQ', token=21938, parent_token=None, symbol='445mh22', name='SDL MH 4.45% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2220200066')),
#              (947,
#               Instrument(exchange='NSE_EQ', token=947, parent_token=None, symbol='448gs2023', name='GOI LOAN  4.48% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020200211')),
#              (22021,
#               Instrument(exchange='NSE_EQ', token=22021, parent_token=None, symbol='449rj23', name='SDL RJ 4.49% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200200')),
#              (21045,
#               Instrument(exchange='NSE_EQ', token=21045, parent_token=None, symbol='44hr23', name='SDL HR 4.4% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1620200064')),
#              (21215,
#               Instrument(exchange='NSE_EQ', token=21215, parent_token=None, symbol='452br23', name='SDL BR 4.52% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200018')),
#              (22108,
#               Instrument(exchange='NSE_EQ', token=22108, parent_token=None, symbol='452tn22', name='SDL TN 4.52% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120200099')),
#              (22268,
#               Instrument(exchange='NSE_EQ', token=22268, parent_token=None, symbol='454br23', name='SDL BR 4.54% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200026')),
#              (21935,
#               Instrument(exchange='NSE_EQ', token=21935, parent_token=None, symbol='454mh22', name='SDL MH 4.54% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2220200041')),
#              (22271,
#               Instrument(exchange='NSE_EQ', token=22271, parent_token=None, symbol='454rj23', name='SDL RJ 4.54% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200242')),
#              (22101,
#               Instrument(exchange='NSE_EQ', token=22101, parent_token=None, symbol='454tn23', name='SDL TN 4.54% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120200198')),
#              (1069,
#               Instrument(exchange='NSE_EQ', token=1069, parent_token=None, symbol='45as23', name='SDL AS 4.5% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220200126')),
#              (21945,
#               Instrument(exchange='NSE_EQ', token=21945, parent_token=None, symbol='463mh23', name='SDL MH 4.63% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2220200090')),
#              (22133,
#               Instrument(exchange='NSE_EQ', token=22133, parent_token=None, symbol='463tn23', name='SDL TN 4.63% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120200172')),
#              (21648,
#               Instrument(exchange='NSE_EQ', token=21648, parent_token=None, symbol='468hr22', name='SDL HR 4.68% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1620200049')),
#              (21641,
#               Instrument(exchange='NSE_EQ', token=21641, parent_token=None, symbol='475hr22', name='SDL HR 4.75% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1620200023')),
#              (21943,
#               Instrument(exchange='NSE_EQ', token=21943, parent_token=None, symbol='476mh23', name='SDL MH 4.76% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2220200082')),
#              (2895,
#               Instrument(exchange='NSE_EQ', token=2895, parent_token=None, symbol='477kl23', name='SDL KL 4.77% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200282')),
#              (2898,
#               Instrument(exchange='NSE_EQ', token=2898, parent_token=None, symbol='477mp23', name='SDL MP 4.77% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2120200281')),
#              (282,
#               Instrument(exchange='NSE_EQ', token=282, parent_token=None, symbol='47kl22', name='SDL KL 4.7% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200191')),
#              (2062,
#               Instrument(exchange='NSE_EQ', token=2062, parent_token=None, symbol='485kl23', name='SDL KL 4.85% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200241')),
#              (22058,
#               Instrument(exchange='NSE_EQ', token=22058, parent_token=None, symbol='489rj23', name='SDL RJ 4.89% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200143')),
#              (22376,
#               Instrument(exchange='NSE_EQ', token=22376, parent_token=None, symbol='493br23', name='SDL BR 4.93% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200034')),
#              (2527,
#               Instrument(exchange='NSE_EQ', token=2527, parent_token=None, symbol='494mp23', name='SDL MP 4.94% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2120200257')),
#              (22106,
#               Instrument(exchange='NSE_EQ', token=22106, parent_token=None, symbol='499tn23', name='SDL TN 4.99% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120200073')),
#              (21918,
#               Instrument(exchange='NSE_EQ', token=21918, parent_token=None, symbol='503kl24', name='SDL KL 5.03% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200159')),
#              (22409,
#               Instrument(exchange='NSE_EQ', token=22409, parent_token=None, symbol='505kl23', name='SDL KL 5.05% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200175')),
#              (22270,
#               Instrument(exchange='NSE_EQ', token=22270, parent_token=None, symbol='505rj24', name='SDL RJ 5.05% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200259')),
#              (8,
#               Instrument(exchange='NSE_EQ', token=8, parent_token=None, symbol='507py23', name='SDL PY 5.07% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3820200019')),
#              (11,
#               Instrument(exchange='NSE_EQ', token=11, parent_token=None, symbol='509cg23', name='SDL CG 5.09% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3520200020')),
#              (18469,
#               Instrument(exchange='NSE_EQ', token=18469, parent_token=None, symbol='509gs2022', name='GOI LOAN 5.09% 2022', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020200021')),
#              (21898,
#               Instrument(exchange='NSE_EQ', token=21898, parent_token=None, symbol='509kl23', name='SDL KL 5.09% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200043')),
#              (22408,
#               Instrument(exchange='NSE_EQ', token=22408, parent_token=None, symbol='509tn23', name='SDL TN 5.09% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120200271')),
#              (1071,
#               Instrument(exchange='NSE_EQ', token=1071, parent_token=None, symbol='512br24', name='SDL BR 5.12% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200091')),
#              (1054,
#               Instrument(exchange='NSE_EQ', token=1054, parent_token=None, symbol='515gs2025', name='GOI LOAN  5.15% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020200278')),
#              (2063,
#               Instrument(exchange='NSE_EQ', token=2063, parent_token=None, symbol='518kl24', name='SDL KL 5.18% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200258')),
#              (22407,
#               Instrument(exchange='NSE_EQ', token=22407, parent_token=None, symbol='51br23', name='SDL BR 5.1% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200042')),
#              (18976,
#               Instrument(exchange='NSE_EQ', token=18976, parent_token=None, symbol='522gs2025', name='GOI LOAN 5.22% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020200112')),
#              (752,
#               Instrument(exchange='NSE_EQ', token=752, parent_token=None, symbol='524as24', name='SDL AS 5.24% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220200092')),
#              (755,
#               Instrument(exchange='NSE_EQ', token=755, parent_token=None, symbol='527br24', name='SDL BR 5.27% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200083')),
#              (152,
#               Instrument(exchange='NSE_EQ', token=152, parent_token=None, symbol='528br23', name='SDL BR 5.28% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200067')),
#              (1210,
#               Instrument(exchange='NSE_EQ', token=1210, parent_token=None, symbol='532as25', name='SDL AS 5.32% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220200159')),
#              (1821,
#               Instrument(exchange='NSE_EQ', token=1821, parent_token=None, symbol='532as26', name='SDL AS 5.32% 2026', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220200191')),
#              (1209,
#               Instrument(exchange='NSE_EQ', token=1209, parent_token=None, symbol='532cg25', name='SDL CG 5.32% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3520200061')),
#              (1700,
#               Instrument(exchange='NSE_EQ', token=1700, parent_token=None, symbol='532rj25', name='SDL RJ 5.32% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200531')),
#              (971,
#               Instrument(exchange='NSE_EQ', token=971, parent_token=None, symbol='535cg25', name='SDL CG 5.35% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3520200053')),
#              (1513,
#               Instrument(exchange='NSE_EQ', token=1513, parent_token=None, symbol='535rj25', name='SDL RJ 5.35% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200523')),
#              (835,
#               Instrument(exchange='NSE_EQ', token=835, parent_token=None, symbol='538cg25', name='SDL CG 5.38% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3520200046')),
#              (22045,
#               Instrument(exchange='NSE_EQ', token=22045, parent_token=None, symbol='538rj24', name='SDL RJ 5.38% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200069')),
#              (3043,
#               Instrument(exchange='NSE_EQ', token=3043, parent_token=None, symbol='539gj24', name='SDL GJ 5.39% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1520200313')),
#              (22339,
#               Instrument(exchange='NSE_EQ', token=22339, parent_token=None, symbol='539rj24', name='SDL RJ 5.39% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200309')),
#              (2011,
#               Instrument(exchange='NSE_EQ', token=2011, parent_token=None, symbol='539rj25', name='SDL RJ 5.39% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200580')),
#              (1207,
#               Instrument(exchange='NSE_EQ', token=1207, parent_token=None, symbol='53br25', name='SDL BR 5.3% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200109')),
#              (283,
#               Instrument(exchange='NSE_EQ', token=283, parent_token=None, symbol='53rj23', name='SDL RJ 5.3% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200390')),
#              (22331,
#               Instrument(exchange='NSE_EQ', token=22331, parent_token=None, symbol='540cg24', name='SDL CG 5.40% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3520200012')),
#              (22334,
#               Instrument(exchange='NSE_EQ', token=22334, parent_token=None, symbol='541ap24', name='SDL AP 5.41% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020200284')),
#              (1697,
#               Instrument(exchange='NSE_EQ', token=1697, parent_token=None, symbol='541ga25', name='SDL GA 5.41% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1420200223')),
#              (2662,
#               Instrument(exchange='NSE_EQ', token=2662, parent_token=None, symbol='542rj24', name='SDL RJ 5.42% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200762')),
#              (3046,
#               Instrument(exchange='NSE_EQ', token=3046, parent_token=None, symbol='543br24', name='SDL BR 5.43% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200166')),
#              (20736,
#               Instrument(exchange='NSE_EQ', token=20736, parent_token=None, symbol='544ap24', name='SDL AP 5.44% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020200185')),
#              (21900,
#               Instrument(exchange='NSE_EQ', token=21900, parent_token=None, symbol='544kl24', name='SDL KL 5.44% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200100')),
#              (22116,
#               Instrument(exchange='NSE_EQ', token=22116, parent_token=None, symbol='544tn23', name='SDL TN 5.44% 2023', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120200032')),
#              (20281,
#               Instrument(exchange='NSE_EQ', token=20281, parent_token=None, symbol='545ap24', name='SDL AP 5.45% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020200151')),
#              (22022,
#               Instrument(exchange='NSE_EQ', token=22022, parent_token=None, symbol='545rj25', name='SDL RJ 5.45% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200218')),
#              (2012,
#               Instrument(exchange='NSE_EQ', token=2012, parent_token=None, symbol='546py25', name='SDL PY 5.46% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3820200068')),
#              (22109,
#               Instrument(exchange='NSE_EQ', token=22109, parent_token=None, symbol='546tn24', name='SDL TN 5.46% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120200107')),
#              (2533,
#               Instrument(exchange='NSE_EQ', token=2533, parent_token=None, symbol='547as24', name='SDL AS 5.47% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220200316')),
#              (22051,
#               Instrument(exchange='NSE_EQ', token=22051, parent_token=None, symbol='547rj24', name='SDL RJ 5.47% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200093')),
#              (22300,
#               Instrument(exchange='NSE_EQ', token=22300, parent_token=None, symbol='549rj25', name='SDL RJ 5.49% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200283')),
#              (587,
#               Instrument(exchange='NSE_EQ', token=587, parent_token=None, symbol='54br24', name='SDL BR 5.4% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200075')),
#              (2722,
#               Instrument(exchange='NSE_EQ', token=2722, parent_token=None, symbol='54kl24', name='SDL KL 5.4% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200274')),
#              (22446,
#               Instrument(exchange='NSE_EQ', token=22446, parent_token=None, symbol='552ap24', name='SDL AP 5.52% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020200326')),
#              (2536,
#               Instrument(exchange='NSE_EQ', token=2536, parent_token=None, symbol='552mp24', name='SDL MP 5.52% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2120200265')),
#              (21917,
#               Instrument(exchange='NSE_EQ', token=21917, parent_token=None, symbol='553kl25', name='SDL KL 5.53% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200142')),
#              (21974,
#               Instrument(exchange='NSE_EQ', token=21974, parent_token=None, symbol='554mp21', name='SDL MP 5.54% 2021', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2120200059')),
#              (22003,
#               Instrument(exchange='NSE_EQ', token=22003, parent_token=None, symbol='562or21', name='SDL OR 5.62% 2021', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2720200038')),
#              (3202,
#               Instrument(exchange='NSE_EQ', token=3202, parent_token=None, symbol='563gs2026', name='GOI LOAN  5.63% 2026', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020210012')),
#              (21907,
#               Instrument(exchange='NSE_EQ', token=21907, parent_token=None, symbol='565kl24', name='SDL KL 5.65% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020200068')),
#              (22052,
#               Instrument(exchange='NSE_EQ', token=22052, parent_token=None, symbol='565rj25', name='SDL RJ 5.65% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200101')),
#              (155,
#               Instrument(exchange='NSE_EQ', token=155, parent_token=None, symbol='568mh24', name='SDL MH 5.68% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2220200173')),
#              (21649,
#               Instrument(exchange='NSE_EQ', token=21649, parent_token=None, symbol='56hr24', name='SDL HR 5.6% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1620200056')),
#              (12,
#               Instrument(exchange='NSE_EQ', token=12, parent_token=None, symbol='56mh24', name='SDL MH 5.6% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2220200140')),
#              (416,
#               Instrument(exchange='NSE_EQ', token=416, parent_token=None, symbol='56rj24', name='SDL RJ 5.6% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200416')),
#              (1886,
#               Instrument(exchange='NSE_EQ', token=1886, parent_token=None, symbol='572br26', name='SDL BR 5.72% 2026', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1320200117')),
#              (21969,
#               Instrument(exchange='NSE_EQ', token=21969, parent_token=None, symbol='573mp21', name='SDL MP 5.73% 2021', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2120200042')),
#              (285,
#               Instrument(exchange='NSE_EQ', token=285, parent_token=None, symbol='575ap24', name='SDL AP 5.75% 2024', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020200375')),
#              (21928,
#               Instrument(exchange='NSE_EQ', token=21928, parent_token=None, symbol='575ka25', name='SDL KA 5.75% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1920200061')),
#              (836,
#               Instrument(exchange='NSE_EQ', token=836, parent_token=None, symbol='575py26', name='SDL PY 5.75% 2026', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3820200035')),
#              (22055,
#               Instrument(exchange='NSE_EQ', token=22055, parent_token=None, symbol='575rj25', name='SDL RJ 5.75% 2025', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200127')),
#              (22105,
# ...
#              (22163,
#               Instrument(exchange='NSE_EQ', token=22163, parent_token=None, symbol='718cg30', name='SDL CG 7.18% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3520190056')),
#              (20696,
#               Instrument(exchange='NSE_EQ', token=20696, parent_token=None, symbol='718gj30', name='SDL GJ 7.18% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1520190175')),
#              (20108,
#               Instrument(exchange='NSE_EQ', token=20108, parent_token=None, symbol='718hp32', name='SDL HP 7.18% 2032', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1720190108')),
#              (2407,
#               Instrument(exchange='NSE_EQ', token=2407, parent_token=None, symbol='718hr41', name='SDL HR 7.18% 2041', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1620200155')),
#              (21912,
#               Instrument(exchange='NSE_EQ', token=21912, parent_token=None, symbol='718kl29', name='SDL KL 7.18% 2029', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2020190178')),
#              (2679,
#               Instrument(exchange='NSE_EQ', token=2679, parent_token=None, symbol='718mn31', name='SDL MN 7.18% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2320200099')),
#              (21972,
#               Instrument(exchange='NSE_EQ', token=21972, parent_token=None, symbol='718mp30', name='SDL MP 7.18% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2120190086')),
#              (22060,
#               Instrument(exchange='NSE_EQ', token=22060, parent_token=None, symbol='718rj29', name='SDL RJ 7.18% 2029', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920190294')),
#              (22072,
#               Instrument(exchange='NSE_EQ', token=22072, parent_token=None, symbol='718rj30', name='SDL RJ 7.18% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920190369')),
#              (2681,
#               Instrument(exchange='NSE_EQ', token=2681, parent_token=None, symbol='718sk31', name='SDL SK 7.18% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3020200066')),
#              (22213,
#               Instrument(exchange='NSE_EQ', token=22213, parent_token=None, symbol='718up30', name='SDL UP 7.18% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3320190173')),
#              (22221,
#               Instrument(exchange='NSE_EQ', token=22221, parent_token=None, symbol='718up30a', name='SDL UP 7.18% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3320190199')),
#              (22144,
#               Instrument(exchange='NSE_EQ', token=22144, parent_token=None, symbol='718wb35', name='SDL WB 7.18% 2035', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3420190164')),
#              (20147,
#               Instrument(exchange='NSE_EQ', token=20147, parent_token=None, symbol='719ap34', name='SDL AP 7.19% 2034', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020190444')),
#              (18474,
#               Instrument(exchange='NSE_EQ', token=18474, parent_token=None, symbol='719gs2060', name='GOI LOAN 7.19% 2060', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=1, instrument_type='EQUITY', isin='IN0020200039')),
#              (20959,
#               Instrument(exchange='NSE_EQ', token=20959, parent_token=None, symbol='719jk29', name='SDL JK 7.19% 2029', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1820190123')),
#              (2768,
#               Instrument(exchange='NSE_EQ', token=2768, parent_token=None, symbol='719ka39', name='SDL KA 7.19% 2039', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1920200699')),
#              (2771,
#               Instrument(exchange='NSE_EQ', token=2771, parent_token=None, symbol='719ka40', name='SDL KA 7.19% 2040', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1920200707')),
#              (21967,
#               Instrument(exchange='NSE_EQ', token=21967, parent_token=None, symbol='719mp40', name='SDL MP 7.19% 2040', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2120190169')),
#              (2384,
#               Instrument(exchange='NSE_EQ', token=2384, parent_token=None, symbol='719sk31', name='SDL SK 7.19% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3020200058')),
#              (22125,
#               Instrument(exchange='NSE_EQ', token=22125, parent_token=None, symbol='719tn30', name='SDL TN 7.19% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120190225')),
#              (22110,
#               Instrument(exchange='NSE_EQ', token=22110, parent_token=None, symbol='719tn35', name='SDL TN 7.19% 2035', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3120190258')),
#              (22092,
#               Instrument(exchange='NSE_EQ', token=22092, parent_token=None, symbol='719up29', name='SDL UP 7.19% 2029', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3320190132')),
#              (2552,
#               Instrument(exchange='NSE_EQ', token=2552, parent_token=None, symbol='719up31', name='SDL UP 7.19% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3320200311')),
#              (22148,
#               Instrument(exchange='NSE_EQ', token=22148, parent_token=None, symbol='719wb29', name='SDL WB 7.19% 2029', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3420190131')),
#              (2762,
#               Instrument(exchange='NSE_EQ', token=2762, parent_token=None, symbol='719wb36', name='SDL WB 7.19% 2036', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3420200286')),
#              (469,
#               Instrument(exchange='NSE_EQ', token=469, parent_token=None, symbol='71ap37', name='SDL AP 7.1% 2037', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020200391')),
#              (20018,
#               Instrument(exchange='NSE_EQ', token=20018, parent_token=None, symbol='71jk30', name='SDL JK 7.1% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1820190156')),
#              (313,
#               Instrument(exchange='NSE_EQ', token=313, parent_token=None, symbol='71mh32', name='SDL MH 7.1% 2032', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2220200207')),
#              (22151,
#               Instrument(exchange='NSE_EQ', token=22151, parent_token=None, symbol='71wb30', name='SDL WB 7.1% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3420190198')),
#              (20518,
#               Instrument(exchange='NSE_EQ', token=20518, parent_token=None, symbol='720ar30', name='SDL AR 7.20% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1120190047')),
#              (20358,
#               Instrument(exchange='NSE_EQ', token=20358, parent_token=None, symbol='720as30', name='SDL AS 7.20% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220190236')),
#              (22010,
#               Instrument(exchange='NSE_EQ', token=22010, parent_token=None, symbol='720ml30', name='SDL ML 7.20% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2420190075')),
#              (22015,
#               Instrument(exchange='NSE_EQ', token=22015, parent_token=None, symbol='720mz30', name='SDL MZ 7.20% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2520190066')),
#              (20575,
#               Instrument(exchange='NSE_EQ', token=20575, parent_token=None, symbol='721ap31', name='SDL AP 7.21% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020190378')),
#              (21977,
#               Instrument(exchange='NSE_EQ', token=21977, parent_token=None, symbol='721mp34', name='SDL MP 7.21% 2034', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2120190078')),
#              (22024,
#               Instrument(exchange='NSE_EQ', token=22024, parent_token=None, symbol='721py28', name='SDL PY 7.21% 2028', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3820190046')),
#              (22139,
#               Instrument(exchange='NSE_EQ', token=22139, parent_token=None, symbol='721tr29', name='SDL TR 7.21% 2029', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3220190034')),
#              (22031,
#               Instrument(exchange='NSE_EQ', token=22031, parent_token=None, symbol='722ap28', name='SDL AP 7.22% 2028', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020190303')),
#              (22030,
#               Instrument(exchange='NSE_EQ', token=22030, parent_token=None, symbol='722ap30', name='SDL AP 7.22% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020190345')),
#              (22215,
#               Instrument(exchange='NSE_EQ', token=22215, parent_token=None, symbol='722ap31', name='SDL AP 7.22% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020190352')),
#              (22032,
#               Instrument(exchange='NSE_EQ', token=22032, parent_token=None, symbol='722ap31a', name='SDL AP 7.22% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020190311')),
#              (2395,
#               Instrument(exchange='NSE_EQ', token=2395, parent_token=None, symbol='722ap37', name='SDL AP 7.22% 2037', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020200581')),
#              (20915,
#               Instrument(exchange='NSE_EQ', token=20915, parent_token=None, symbol='722as29', name='SDL AS 7.22% 2029', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220190103')),
#              (20850,
#               Instrument(exchange='NSE_EQ', token=20850, parent_token=None, symbol='722as30', name='SDL AS 7.22% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220190152')),
#              (20916,
#               Instrument(exchange='NSE_EQ', token=20916, parent_token=None, symbol='722ga29', name='SDL GA 7.22% 2029', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1420190127')),
#              (2398,
#               Instrument(exchange='NSE_EQ', token=2398, parent_token=None, symbol='722ka38', name='SDL KA 7.22% 2038', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1920200590')),
#              (2578,
#               Instrument(exchange='NSE_EQ', token=2578, parent_token=None, symbol='722ka38a', name='SDL KA 7.22% 2038', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1920200640')),
#              (21893,
#               Instrument(exchange='NSE_EQ', token=21893, parent_token=None, symbol='722pn32', name='SDL PN 7.22% 2032', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2820190113')),
#              (2413,
#               Instrument(exchange='NSE_EQ', token=2413, parent_token=None, symbol='722rj41', name='SDL RJ 7.22% 2041', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2920200721')),
#              (22089,
#               Instrument(exchange='NSE_EQ', token=22089, parent_token=None, symbol='722up30', name='SDL UP 7.22% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3320190181')),
#              (21710,
#               Instrument(exchange='NSE_EQ', token=21710, parent_token=None, symbol='723ka28', name='SDL KA 7.23% 2028', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1920190098')),
#              (2557,
#               Instrument(exchange='NSE_EQ', token=2557, parent_token=None, symbol='723pn31', name='SDL PN 7.23% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN2820200201')),
#              (22147,
#               Instrument(exchange='NSE_EQ', token=22147, parent_token=None, symbol='723wb30', name='SDL WB 7.23% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3420190172')),
#              (2414,
#               Instrument(exchange='NSE_EQ', token=2414, parent_token=None, symbol='723wb41', name='SDL WB 7.23% 2041', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN3420200260')),
#              (21644,
#               Instrument(exchange='NSE_EQ', token=21644, parent_token=None, symbol='724ap33', name='SDL AP 7.24% 2033', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020190428')),
#              (21645,
#               Instrument(exchange='NSE_EQ', token=21645, parent_token=None, symbol='724ap35', name='SDL AP 7.24% 2035', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1020190436')),
#              (20917,
#               Instrument(exchange='NSE_EQ', token=20917, parent_token=None, symbol='724as30', name='SDL AS 7.24% 2030', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220190178')),
#              (2389,
#               Instrument(exchange='NSE_EQ', token=2389, parent_token=None, symbol='724as31', name='SDL AS 7.24% 2031', closing_price=None, expiry=None, strike_price=None, tick_size=1.0, lot_size=100, instrument_type='EQUITY', isin='IN1220200308')),
#              ...])

# %%
reliance_nse_eq = u.get_instrument_by_symbol('NSE_EQ', 'RELIANCE')
reliance_nse_eq
# Out:
# Instrument(exchange='NSE_EQ', token=2885, parent_token=None, symbol='reliance', name='RELIANCE INDUSTRIES LTD', closing_price=2002.55, expiry=None, strike_price=None, tick_size=5.0, lot_size=1, instrument_type='EQUITY', isin='INE002A01018')

# %%
u.get_live_feed(u.get_instrument_by_symbol('NSE_EQ', 'ACC'), LiveFeedType.LTP)
# Out:
# {'timestamp': 1621332001000,
#  'exchange': 'NSE_EQ',
#  'symbol': 'ACC',
#  'ltp': 1936.2,
#  'close': 1903.6}

# %%
print ("%%%%%%%%%%%%%%%%%%%%%%%%%%%%1%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print(
   u.place_order(TransactionType.Buy,  #transaction_type
              u.get_instrument_by_symbol('NSE_EQ', 'RELIANCE'),  #instrument
              1,  # quantity
              OrderType.Market,  # order_type
              ProductType.Delivery,  # product_type
              0.0,  # price
              None,  # trigger_price
              1,  # disclosed_quantity
              DurationType.DAY, # duration
              None, # stop_loss
              None, # square_off
              None )# trailing_ticks
   )
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%1%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# {'client_id': 'KF6449', 'exchange': 'NSE_EQ', 'token': 2885, 'symbol': 'RELIANCE', 'product': 'D', 'order_type': 'M', 'duration': 'DAY', 'price': 0, 'trigger_price': 0, 'quantity': 1, 'disclosed_quantity': 1, 'transaction_type': 'B', 'average_price': 0, 'traded_quantity': 0, 'message': '', 'exchange_order_id': '', 'parent_order_id': 'NA', 'order_id': '210522000013624', 'exchange_time': '', 'time_in_micro': '1621667520699132', 'status': 'put order req received', 'is_amo': False, 'valid_date': '', 'order_request_id': '1', 'report': '', 'text': '', 'user_comment': '', 'trading_symbol': 'RELIANCE', 'series': 'EQ'}
