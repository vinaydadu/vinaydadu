# %%
# !pip install pytrends
# Out:
# ...
#   Using cached pytrends-4.7.3-py3-none-any.whl (14 kB)
# ...

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
pytrend.build_payload(kw_list=['Ambani'])
# Interest by Region
df = pytrend.interest_by_region()
df.head(200)
# Out:
#                                         Ambani
# geoName
# Afghanistan                                  0
# Albania                                      0
# Algeria                                      0
# American Samoa                               0
# Andorra                                      0
# ...                                        ...
# Solomon Islands                              0
# Somalia                                      0
# South Africa                                 3
# South Georgia & South Sandwich Islands       0
# South Korea                                  0
#
# [200 rows x 1 columns]

# %%
df.reset_index().plot(x='geoName', y='Ambani', figsize=(120, 10), kind ='bar')
# Out:
# <AxesSubplot:xlabel='geoName'>

# %%
df = pytrend.trending_searches(pn='india')
df.head()
# Out:
#                        0
# 0     Telangana lockdown
# 1           Mehul Choksi
# 2          Boris Johnson
# 3  Lockdown in Telangana
# 4            French Open

# %%
df = pytrend.today_searches(pn='US')
df
# Out:
# 0       French Open
# 1    Carrie Symonds
# 2     Gwen Shamblin
# 3     Kamala Harris
# Name: query, dtype: object

# %%
# Get Google Top Charts
df = pytrend.top_charts(2020, hl='en-US', tz=300, geo='GLOBAL')
df.head()
# Out:
#               title exploreQuery
# 0       Coronavirus
# 1  Election results
# 2       Kobe Bryant
# 3              Zoom
# 4               IPL

# %%
# Get Google Keyword Suggestions
keywords = pytrend.suggestions(keyword='sputnik v')
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')   # This column makes no sense
# Out:
#                title            type
# 0  Sputnik virophage           Topic
# 1   Korabl-Sputnik 2           Topic
# 2   COVID-19 vaccine  Pharmaceutical
# 3            Sputnik     News agency
# 4          Sputnik 1       Satellite

# %%
# Related Queries, returns a dictionary of dataframes
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                       query  value
# 0             mukesh ambani    100
# 1                    mukesh     99
# 2               anil ambani     31
# 3                      anil     31
# 4               nita ambani     28
# 5              ambani house     28
# 6               isha ambani     25
# 7          dhirubhai ambani     18
# 8          ambani net worth     18
# 9              akash ambani     15
# 10      mukesh ambani house     14
# 11                    india     14
# 12           ambani wedding     13
# 13  mukesh ambani net worth     12
# 14               ambani son     10
# 15             anant ambani      8
# 16          ambani daughter      7
# 17              ambani wife      7
# 18                 reliance      7
# 19            ambani family      7
# 20            ambani school      6
# 21              tina ambani      6
# 22                   mumbai      6
# 23              ambani news      6
# ...

# %%
# Related Topics, returns a dictionary of dataframes
related_topic = pytrend.related_topics()
related_topic.values()
# Out:
# dict_values([{'rising':      value formattedValue                                            link  \
# 0   131200       Breakout  /trends/explore?q=/g/11fj77t1m2&date=today+5-y
# 1    28700       Breakout     /trends/explore?q=/m/0wxqr3r&date=today+5-y
# 2    18350       Breakout  /trends/explore?q=/g/11byw_jxnr&date=today+5-y
# 3     4750        +4,750%      /trends/explore?q=/m/011z69&date=today+5-y
# 4     3200        +3,200%      /trends/explore?q=/m/03nzf1&date=today+5-y
# 5     1850        +1,850%       /trends/explore?q=/m/09t3w&date=today+5-y
# 6     1200        +1,200%     /trends/explore?q=/m/01mpq7s&date=today+5-y
# 7     1000        +1,000%     /trends/explore?q=/m/0wzx4rf&date=today+5-y
# 8      950          +950%      /trends/explore?q=/m/0204sn&date=today+5-y
# 9      900          +900%       /trends/explore?q=/m/09qd1&date=today+5-y
# 10     900          +900%      /trends/explore?q=/m/0bmtvm&date=today+5-y
# ...
