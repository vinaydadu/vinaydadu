# %%
pip install nsepython
# Out:
# Collecting nsepython
#   Downloading nsepython-0.0.94-py3-none-any.whl (17 kB)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from nsepython) (1.1.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from nsepython) (2.24.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->nsepython) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\programdata\anaconda3\lib\site-packages (from pandas->nsepython) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->nsepython) (2020.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->nsepython) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->nsepython) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->nsepython) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->nsepython) (1.25.11)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->nsepython) (1.15.0)
# Installing collected packages: nsepython
# Successfully installed nsepython-0.0.94
# Note: you may need to restart the kernel to use updated packages.

# %%
from nsepython import *   
import warnings
warnings.simplefilter('ignore')

# %%
print(fnolist())
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 24520
# ['NIFTY', 'NIFTYIT', 'BANKNIFTY', 'FEDERALBNK', 'PAGEIND', 'DLF', 'GODREJPROP', 'MANAPPURAM', 'ULTRACEMCO', 'AMBUJACEM', 'MUTHOOTFIN', 'TATACHEM', 'SHREECEM', 'LICHSGFIN', 'PFC', 'RAMCOCEM', 'JSWSTEEL', 'GRASIM', 'ICICIPRULI', 'BEL', 'HAVELLS', 'TATACONSUM', 'RECLTD', 'IRCTC', 'ACC', 'APOLLOTYRE', 'CONCOR', 'DEEPAKNTR', 'ICICIGI', 'TRENT', 'BALKRISIND', 'ICICIBANK', 'MOTHERSUMI', 'BHARATFORG', 'UPL', 'APOLLOHOSP', 'HDFCAMC', 'TATAMOTORS', 'CANBK', 'KOTAKBANK', 'MARUTI', 'TVSMOTOR', 'IDFCFIRSTB', 'IBULHSGFIN', 'INDUSINDBK', 'EXIDEIND', 'SBIN', 'SIEMENS', 'WIPRO', 'MCDOWELL-N', 'L&TFH', 'RELIANCE', 'LALPATHLAB', 'VOLTAS', 'GUJGASLTD', 'IDEA', 'JINDALSTEL', 'SBILIFE', 'M&MFIN', 'UBL', 'ASHOKLEY', 'SAIL', 'COFORGE', 'PEL', 'AXISBANK', 'CADILAHC', 'HEROMOTOCO', 'NAUKRI', 'HCLTECH', 'RBLBANK', 'GAIL', 'SUNTV', 'NTPC', 'SRTRANSFIN', 'AARTIIND', 'LUPIN', 'INDHOTEL', 'EICHERMOT', 'TORNTPHARM', 'BAJFINANCE', 'ONGC', 'BANDHANBNK', 'CUB', 'MRF', 'INDIGO', 'ITC', 'BERGEPAINT', 'PFIZER', 'SUNPHARMA', 'BRITANNIA', 'AMARAJABAT', 'MARICO', 'TCS', 'NESTLEIND', 'PNB', 'DRREDDY', 'ABFRL', 'TECHM', 'ALKEM', 'NMDC', 'IGL', 'BATAINDIA', 'CIPLA', 'COLPAL', 'MGL', 'CHOLAFIN', 'TATASTEEL', 'IOC', 'LT', 'TITAN', 'COALINDIA', 'HDFCLIFE', 'ESCORTS', 'BANKBARODA', 'BOSCHLTD', 'APLLTD', 'BHEL', 'BAJAJFINSV', 'ADANIENT', 'GRANULES', 'DIVISLAB', 'M&M', 'VEDL', 'SRF', 'AUROPHARMA', 'DABUR', 'TORNTPOWER', 'PIDILITIND', 'JUBLFOOD', 'TATAPOWER', 'LTTS', 'GMRINFRA', 'ZEEL', 'INFY', 'BAJAJ-AUTO', 'ASIANPAINT', 'PETRONET', 'HINDALCO', 'MFSL', 'BIOCON', 'HDFC', 'NAVINFLUOR', 'NATIONALUM', 'POWERGRID', 'HINDUNILVR', 'AUBANK', 'MPHASIS', 'LTI', 'HDFCBANK', 'CUMMINSIND', 'PVR', 'ADANIPORTS', 'NAM-INDIA', 'INDUSTOWER', 'MINDTREE', 'GODREJCP', 'COROMANDEL', 'BHARTIARTL', 'BPCL', 'PIIND', 'GLENMARK', 'HINDPETRO', 'METROPOLIS']

# %%
def running_status(): 
    start_now=datetime.datetime.now().replace(hour=9, minute=15, second=0, microsecond=0)
    end_now=datetime.datetime.now().replace(hour=15, minute=30, second=0, microsecond=0)
    return start_now<datetime.datetime.now()<end_now

# %%
print(nse_optionchain_scrapper('NIFTY'))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/option-chain-indices?symbol=NIFTY HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40655
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/option-chain-indices?symbol=NIFTY HTTP/1.1" 200 74399
# {'records': {'expiryDates': ['03-Jun-2021', '10-Jun-2021', '17-Jun-2021', '24-Jun-2021', '01-Jul-2021', '08-Jul-2021', '15-Jul-2021', '22-Jul-2021', '29-Jul-2021', '26-Aug-2021', '30-Sep-2021', '30-Dec-2021', '31-Mar-2022', '30-Jun-2022', '29-Dec-2022', '29-Jun-2023', '28-Dec-2023', '27-Jun-2024', '26-Dec-2024', '26-Jun-2025', '24-Dec-2025'], 'data': [{'strikePrice': 6000, 'expiryDate': '24-Jun-2021', 'PE': {'strikePrice': 6000, 'expiryDate': '24-Jun-2021', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2021PE6000.00', 'openInterest': 282, 'changeinOpenInterest': 4, 'pchangeinOpenInterest': 1.4388489208633093, 'totalTradedVolume': 56, 'impliedVolatility': 119.83, 'lastPrice': 1.55, 'change': -1.8, 'pChange': -53.73134328358209, 'totalBuyQuantity': 20850, 'totalSellQuantity': 31800, 'bidQty': 375, 'bidprice': 1.55, 'askQty': 75, 'askPrice': 1.85, 'underlyingValue': 15435.65}}, {'strikePrice': 7500, 'expiryDate': '29-Dec-2022', 'PE': {'strikePrice': 7500, 'expiryDate': '29-Dec-2022', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-12-2022PE7500.00', 'openInterest': 14, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 235, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 5400, 'totalSellQuantity': 0, 'bidQty': 750, 'bidprice': 7.55, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 15435.65}}, {'strikePrice': 7600, 'expiryDate': '29-Dec-2022', 'PE': {'strikePrice': 7600, 'expiryDate': '29-Dec-2022', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-12-2022PE7600.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 80, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 750, 'totalSellQuantity': 0, 'bidQty': 750, 'bidprice': 7.35, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 15435.65}}, {'strikePrice': 8000, 'expiryDate': '30-Dec-2021', 'PE': {'strikePrice': 8000, 'expiryDate': '30-Dec-2021', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-12-2021PE8000.00', 'openInterest': 16, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 1.15, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 6600, 'totalSellQuantity': 0, 'bidQty': 225, 'bidprice': 3.45, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 15435.65}}, {'strikePrice': 8100, 'expiryDate': '24-Jun-2021', 'PE': {'strikePrice': 8100, 'expiryDate': '24-Jun-2021', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2021PE8100.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 3.85, 'change': 0.3500000000000001, 'pChange': 10.000000000000002, 'totalBuyQuantity': 750, 'totalSellQuantity': 0, 'bidQty': 750, 'bidprice': 0.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 15435.65}}, {'strikePrice': 8200, 'expiryDate': '24-Jun-2021', 'PE': {'strikePrice': 8200, 'expiryDate': '24-Jun-2021', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2021PE8200.00', 'openInterest': 8, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 3.1, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 750, 'totalSellQuantity': 0, 'bidQty': 750, 'bidprice': 0.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 15435.65}}, {'strikePrice': 8300, 'expiryDate': '30-Jun-2022', 'PE': {'strikePrice': 8300, 'expiryDate': '30-Jun-2022', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-06-2022PE8300.00', 'openInterest': 2, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 93.75, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 5250, 'totalSellQuantity': 0, 'bidQty': 750, 'bidprice': 3.75, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 15435.65}}, {'strikePrice': 8300, 'expiryDate': '24-Jun-2021', 'PE': {'strikePrice': 8300, 'expiryDate': '24-Jun-2021', 'underlying': 'NIFTY', 'identif ...

# %%
oi_data, ltp, crontime = oi_chain_builder("PVR","latest","full")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/option-chain-equities?symbol=PVR HTTP/1.1" 200 8416

# %%
print(nse_eq("JUSTDIAL")['priceInfo']['lastPrice'])
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-equity?symbol=JUSTDIAL HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40617
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-equity?symbol=JUSTDIAL HTTP/1.1" 200 894
# 915

# %%
print(nse_fno("PVR"))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=PVR HTTP/1.1" 200 14794
# {'info': {'symbol': 'PVR', 'companyName': 'PVR Limited', 'industry': 'MEDIA & ENTERTAINMENT', 'activeSeries': ['EQ'], 'debtSeries': [], 'tempSuspendedSeries': ['BE'], 'isFNOSec': True, 'isCASec': False, 'isSLBSec': True, 'isDebtSec': False, 'isSuspended': False, 'isETFSec': False, 'isDelisted': False, 'isin': 'INE191H01014'}, 'underlyingValue': 1366.65, 'vfq': 32561, 'fut_timestamp': '12-Jul-2021 13:28:53', 'opt_timestamp': '12-Jul-2021 13:28:09', 'stocks': [{'metadata': {'instrumentType': 'Stock Options', 'expiryDate': '29-Jul-2021', 'optionType': 'Call', 'strikePrice': 1400, 'identifier': 'OPTSTKPVR29-07-2021CE1400.00', 'openPrice': 42, 'highPrice': 42, 'lowPrice': 32.2, 'closePrice': 0, 'prevClose': 42.35, 'lastPrice': 34.7, 'change': -7.649999999999999, 'pChange': -18.063754427390787, 'numberOfContractsTraded': 807, 'totalTurnover': 113.91}, 'underlyingValue': 1366.65, 'volumeFreezeQuantity': 32561, 'marketDeptOrderBook': {'totalBuyQuantity': 54538, 'totalSellQuantity': 56166, 'bid': [{'price': 34.35, 'quantity': 407}, {'price': 34.3, 'quantity': 814}, {'price': 34.15, 'quantity': 407}, {'price': 34.1, 'quantity': 407}, {'price': 34, 'quantity': 407}], 'ask': [{'price': 34.7, 'quantity': 407}, {'price': 35.25, 'quantity': 407}, {'price': 35.3, 'quantity': 407}, {'price': 35.4, 'quantity': 407}, {'price': 35.6, 'quantity': 814}], 'carryOfCost': {'price': {'bestBuy': 34.35, 'bestSell': 34.7, 'lastPrice': 34.7}, 'carry': {'bestBuy': -7908.72499298977, 'bestSell': -7886.958822849616, 'lastPrice': -7886.958822849616}}, 'tradeInfo': {'tradedVolume': 807, 'value': 113.91, 'vmap': 34.68, 'premiumTurnover': 4712.1921132, 'openInterest': 398, 'changeinOpenInterest': -20, 'pchangeinOpenInterest': -4.784688995215311, 'marketLot': 407}, 'otherInfo': {'settlementPrice': 0, 'dailyvolatility': 2.83, 'annualisedVolatility': 54.06, 'impliedVolatility': 39.96, 'clientWisePositionLimits': 0, 'marketWidePositionLimits': 10078782}}}, {'metadata': {'instrumentType': 'Stock Futures', 'expiryDate': '29-Jul-2021', 'optionType': '-', 'strikePrice': 0, 'identifier': 'FUTSTKPVR29-07-2021XX0.00', 'openPrice': 1385, 'highPrice': 1385, 'lowPrice': 1367.1, 'closePrice': 0, 'prevClose': 1383.15, 'lastPrice': 1368, 'change': -15.150000000000091, 'pChange': -1.095325886563286, 'numberOfContractsTraded': 689, 'totalTurnover': 3848.81}, 'underlyingValue': 1366.65, 'volumeFreezeQuantity': 0, 'marketDeptOrderBook': {'totalBuyQuantity': 83842, 'totalSellQuantity': 102157, 'bid': [{'price': 1367.55, 'quantity': 407}, {'price': 1367.5, 'quantity': 407}, {'price': 1367.15, 'quantity': 407}, {'price': 1367.1, 'quantity': 407}, {'price': 1367.05, 'quantity': 407}], 'ask': [{'price': 1369.85, 'quantity': 407}, {'price': 1369.9, 'quantity': 407}, {'price': 1370.05, 'quantity': 407}, {'price': 1370.2, 'quantity': 407}, {'price': 1370.3, 'quantity': 407}], 'carryOfCost': {'price': {'bestBuy': 1367.55, 'bestSell': 1369.85, 'lastPrice': 1368}, 'carry': {'bestBuy': 1.4134686643006245, 'bestSell': 5.021444448753721, 'lastPrice': 2.1198542023484546}}, 'tradeInfo': {'tradedVolume': 689, 'value': 3848.81, 'vmap': 1372.5, 'premiumTurnover': 3848.805675, 'openInterest': 3408, 'changeinOpenInterest': 36, 'pchangeinOpenInterest': 1.0676156583629892, 'marketLot': 407}, 'otherInfo': {'settlementPrice': 1383.15, 'dailyvolatility': 2.83, 'annualisedVolatility': 54.06, 'impliedVolatility': 0, 'clientWisePositionLimits': 0, 'marketWidePositionLimits': 10078782}}}, {'metadata': {'instrumentType': 'Stock Options', 'expiryDate': '29-Jul-2021', 'optionType': 'Call', 'strikePrice': 1380, 'identifier': 'OPTSTKPVR29-07-2021CE1380.00', 'openPrice': 48.65, 'highPrice': 48.65, 'lowPrice': 40, 'closePrice': 0, 'prevClose': 50.25, 'lastPrice': 41.35, 'change': -8.899999999999999, 'pChange': -17.711442786069647, 'numberOfContractsTraded': 423, 'totalTurnover': 74.17}, 'underlyingValue': 1366.65, 'volumeFreezeQuantity': 32561, 'marketDeptOrderBook': {'totalBuyQuantity': 51689, 'totalSellQuantity': 4436 ...

# %%
print(pd.json_normalize(nse_holidays()['FO']))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/holiday-master?type=trading HTTP/1.1" 200 974
#     tradingDate    weekDay                     description  Sr_no
# 0   26-Jan-2021    Tuesday                    Republic Day      1
# 1   11-Mar-2021   Thursday                   Mahashivratri      2
# 2   29-Mar-2021     Monday                            Holi      3
# 3   02-Apr-2021     Friday                     Good Friday      4
# 4   14-Apr-2021  Wednesday  Dr.Baba Saheb Ambedkar Jayanti      5
# 5   21-Apr-2021  Wednesday                      Ram Navami      6
# 6   25-Apr-2021     Sunday                 Mahavir Jayanti      7
# 7   01-May-2021   Saturday                 Maharashtra Day      8
# 8   13-May-2021   Thursday          Id-Ul-Fitr (Ramzan ID)      9
# 9   21-Jul-2021  Wednesday                        Bakri Id     10
# 10  15-Aug-2021     Sunday                Independence Day     11
# 11  19-Aug-2021   Thursday                        Moharram     12
# 12  10-Sep-2021     Friday                Ganesh Chaturthi     13
# 13  02-Oct-2021   Saturday          Mahatma Gandhi Jayanti     14
# 14  15-Oct-2021     Friday                        Dussehra     15
# 15  05-Nov-2021     Friday            Diwali-Balipratipada     16
# 16  19-Nov-2021     Friday               Gurunanak Jayanti     17
# 17  25-Dec-2021   Saturday                       Christmas     18

# %%
nse_results("equities","Others")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/corporates-financial-results?index=equities&period=Others HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40661
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/corporates-financial-results?index=equities&period=Others HTTP/1.1" 200 2
# Empty DataFrame
# Columns: []
# Index: []

# %%
nse_results()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/corporates-financial-results?index=equities&period=Quarterly HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40973
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/corporates-financial-results?index=equities&period=Quarterly HTTP/1.1" 200 1018
#        symbol                            companyName industry     audited  \
# 0        BEPL  Bhansali Engineering Polymers Limited        -  Un-Audited
# 1        BEPL  Bhansali Engineering Polymers Limited        -  Un-Audited
# 2   DELTACORP                     Delta Corp Limited        -  Un-Audited
# 3   DELTACORP                     Delta Corp Limited        -  Un-Audited
# 4       DMART              Avenue Supermarts Limited        -  Un-Audited
# 5       DMART              Avenue Supermarts Limited        -  Un-Audited
# 6       EXCEL           Excel Realty N Infra Limited        -  Un-Audited
# 7       EXCEL           Excel Realty N Infra Limited        -  Un-Audited
# 8       LIBAS        Libas Consumer Products Limited        -  Un-Audited
# 9       LIBAS        Libas Consumer Products Limited        -  Un-Audited
# 10     PILITA          PIL ITALICA LIFESTYLE LIMITED        -  Un-Audited
# 11        TCS      Tata Consultancy Services Limited        -     Audited
# 12        TCS      Tata Consultancy Services Limited        -     Audited
#
#         cumulative       indAs reInd     period     relatingTo  \
# 0   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 1   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 2   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 3   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 4   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 5   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 6   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 7   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 8   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 9   Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 10  Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 11  Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
# 12  Non-cumulative  Ind-AS New     N  Quarterly  First Quarter
#
#                  financialYear  ...     fromDate       toDate oldNewFlag  \
# 0   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 1   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 2   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 3   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 4   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 5   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 6   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 7   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 8   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 9   01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 10  01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 11  01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
# 12  01-Apr-2021 To 31-Mar-2022  ...  01-Apr-2021  30-Jun-2021          N
#
#                                                  xbrl format  \
# 0   https://archives.nseindia.com/corporate/xbrl/I...    New
# 1   https://archives.nseindia.com/corporate/xbrl/I...    New
# 2   https://archives.nseindia.com/corporate/xbrl/I...    New
# 3   https://archives.nseindia.com/corporate/xbrl/I...    New
# 4   https://archives.nseindia.com/corporate/xbrl/I...    New
# 5   https://archives.nseindia.com/corporate/xbrl/I...    New
# 6   https://archives.nseindia.com/corporate/xbrl/I...    New
# 7   https://archives.nseindia.com/corporate/xbrl/I...    New
# 8   https://archives.nseindia.com/corporate/xbrl/I...    New
# 9   https://archives.nseindia.com/corporate/xbrl/I...    New
# 10  https://archives.nseindia.com/corporate/xbrl/I...    New
# 11  https://archives.nseindia.com/corporate/xbrl/I...    New
# 12  https://archives.nseindia.com/corporate/xbrl/I...    New
#
#                                      params resultDescription  \
# 0        01-Apr-202130-Jun-2021Q1UNNNNEBEPL              None
# 1        01-Apr-202130-Jun-2021Q1UNNCNEBEPL              None
# 2   01-Apr-202130-Jun-2021Q1UNNNNEDELTACORP              None
# 3   01-Apr-202130-Jun-2021Q1UNNCNEDELTACORP              None
# 4       01-Apr-202130-Jun-2021Q1UNNNNEDMART              None
# 5       01-Apr-202130-Jun-2021Q1UNNCNEDMART              None
# 6       01-Apr-202130-Jun-2021Q1UNNCNEEXCEL              None
# 7       01-Apr-202130-Jun-2021Q1UNNNNEEXCEL              None
# 8       01-Apr-202130-Jun-2021Q1UNNNNELIBAS              None
# 9       01-Apr-202130-Jun-2021Q1UNNCNELIBAS              None
# 10     01-Apr-202130-Jun-2021Q1UNNNNEPILITA              None
# 11        01-Apr-202130-Jun-2021Q1ANNNNETCS              None
# 12        01-Apr-202130-Jun-2021Q1ANNCNETCS              None
#
#    resultDetailedDataLink      consolidated          isin
# 0                    None  Non-Consolidated  INE922A01025
# 1                    None      Consolidated  INE922A01025
# 2                    None  Non-Consolidated  INE124G01033
# 3                    None      Consolidated  INE124G01033
# 4                    None  Non-Consolidated  INE192R01011
# 5                    None      Consolidated  INE192R01011
# 6                    None      Consolidated  INE688J01015
# 7                    None  Non-Consolidated  INE688J01015
# 8                    None  Non-Consolidated  INE908V01012
# 9                    None      Consolidated  INE908V01012
# 10                   None  Non-Consolidated  INE600A01027
# 11                   None  Non-Consolidated  INE467B01029
# 12                   None      Consolidated  INE467B01029
#
# [13 rows x 23 columns]

# %%
print(nse_past_results('JUSTDIAL'))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/results-comparision?symbol=JUSTDIAL HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40543
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/results-comparision?symbol=JUSTDIAL HTTP/1.1" 200 3629
# {'resCmpData': [{'re_to_dt': '31-MAR-2021', 're_from_dt': '01-JAN-2021', 're_create_dt': '15-MAY-2021', 're_res_type': 'U', 're_excepn_items_new': '0', 're_desc_note_seg': '-', 're_staff_cost': '11763', 're_tot_exp_exc_pro_cont': None, 're_grs_npa': None, 're_int_expd': None, 're_con_pro_loss': '3357', 're_net_sale': '17568', 're_oth_exp': '2351', 're_rawmat_consump': '0', 're_diluted_eps': None, 're_inc_dre_sttr': '0', 're_pur_trd_goods': '0', 're_face_val': '10', 're_income_inv': None, 're_deff_tax': '-138', 're_share_associate': '0', 're_ret_asset': None, 're_proloss_ord_act': '3357', 're_notes_to_ac': '', 're_grs_npa_per': None, 're_excepn_items': None, 're_int_new': '177', 're_pro_los_frm_dis_opr': '0', 're_goi_per_shhd': None, 're_basic_eps_for_cont_dic_opr': '5.43', 're_oth_oper_exp': None, 're_remarks': None, 're_oth_pro_cont': None, 're_seg_remarks': None, 're_face_value_debt': None, 're_dilut_eps_for_cont_dic_opr': '5.29', 're_desc_note_fin': 'Notes pertaining to financial results and Cash Flow are not being separately provided on account of restriction of 4000 words.         Error in XBRL excel  template:      While selecting ￢ﾀﾜwhether results are audited or unaudited￢ﾀﾝ in general info category ￢ﾀﾓ we have selected ￢ﾀﾜunaudited￢ﾀﾝ for the current quarter as we have adopted unaudited results for the Quarter ended March 31, 2021 and Audited results for the Year ended March 31, 2021.       However, in ￢ﾀﾜwhether results are audited or unaudited￢ﾀﾝ in OCI category and Cash flow statement, indirect category in ￢ﾀﾜyear to date figures for current period ended (dd-mm-yyyy)￢ﾀﾝ and ￢ﾀﾜyear ended (dd-mm-yyyy)￢ﾀﾝ respectively we are not able to select ￢ﾀﾜaudited￢ﾀﾝ for the current quarter and shows error message as ￢ﾀﾜThe cell or chart that you are trying to change is protected and therefore read only. To modify or protected cell or chart, first remove protection using the unprotected sheet (Review tab, change group). You may be prompted for password￢ﾀﾝ.', 're_per_grs_npa': None, 're_pro_loss_bef_tax': '3892', 're_pro_loss_bef_tax_sum': None, 're_res_reval': None, 're_int_ser_cov': None, 're_cap_ade_rat': None, 're_paid_debt': None, 're_int_dis_adv_bills': None, 're_prolos_dis_opr_aftr_tax': '0', 're_debt_eqt_rat': None, 're_oth': None, 're_pdup': '6188', 're_curr_tax': '673', 're_debt_ser_cov': None, 're_oth_inc': None, 're_tax': '535', 're_net_profit': '3357', 're_basic_eps': None, 're_tax_expens_of_dis_opr': '0', 're_dil_eps_bfr_exi': None, 're_int_earned': None, 're_depr_und_exp': '942', 're_amt_grs_np_asst': None, 're_prov_emp_pay': None, 're_total_inc': '19125', 're_oth_inc_new': '1557', 're_oper_exp': None, 're_minority_int': None, 're_bal_rbi_oth_bnk_funds': None, 're_cet_1_ret': None, 're_oper_exp_bef_pro_cont': None, 're_debt_rdmption': None, 're_extraord_items': None, 're_oth_tot_exp': '15233', 're_seq_num': '1107671', 're_pro_aft_int_bef_excep': None, 're_bsc_eps_bfr_exi': None, 're_tot_inc': None}, {'re_to_dt': '31-DEC-2020', 're_from_dt': '01-OCT-2020', 're_create_dt': '29-JAN-2021', 're_res_type': 'U', 're_excepn_items_new': '0', 're_desc_note_seg': '-', 're_staff_cost': '11167', 're_tot_exp_exc_pro_cont': None, 're_grs_npa': None, 're_int_expd': None, 're_con_pro_loss': '4994', 're_net_sale': '16954', 're_oth_exp': '1972', 're_rawmat_consump': '0', 're_diluted_eps': None, 're_inc_dre_sttr': '0', 're_pur_trd_goods': '0', 're_face_val': '10', 're_income_inv': None, 're_deff_tax': '141', 're_share_associate': '0', 're_ret_asset': None, 're_proloss_ord_act': '4994', 're_notes_to_ac': '', 're_grs_npa_per': None, 're_excepn_items': None, 're_int_new': '162', 're_pro_los_frm_dis_opr': '0', 're_goi_per_shhd': None, 're_basic_eps_for_cont_dic_opr': '8.08', 're_oth_oper_exp': None, 're_remarks': None, 're_oth_pro_cont': None, 're_seg_remarks': None, 're_face_value_debt': None, 're_dilut_eps_for_cont_dic_opr': '7.9', 're_desc_note_fin': 'Notes:  n  n1. The Unaudited Standalone and Consolidated Financial Results for the  ...

# %%
nse_events()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/event-calendar HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40909
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/event-calendar HTTP/1.1" 200 5666
#          symbol                              company  \
# 0         AAVAS             Aavas Financiers Limited
# 1           BCG              Brightcom Group Limited
# 2     SAGARDEEP             Sagardeep Alloys Limited
# 3      SPANDANA  Spandana Sphoorty Financial Limited
# 4    TATAMETALI                Tata Metaliks Limited
# ..          ...                                  ...
# 155   ESABINDIA                   Esab India Limited
# 156    MINDTECK             Mindteck (India) Limited
# 157   AKZOINDIA             Akzo Nobel India Limited
# 158     TVTODAY             TV Today Network Limited
# 159  AMARAJABAT         Amara Raja Batteries Limited
#
#                                       purpose  \
# 0                      Other business matters
# 1         Fund Raising/Other business matters
# 2                      Other business matters
# 3                                Fund Raising
# 4                           Financial Results
# ..                                        ...
# 155                         Financial Results
# 156  Financial Results/Other business matters
# 157                         Financial Results
# 158                         Financial Results
# 159                         Financial Results
#
#                                                bm_desc         date
# 0    To consider and approve Equity Stock Option Pl...  13-Jul-2021
# 1    Intimation of Board Meeting for Preferential I...  13-Jul-2021
# 2                   To consider other business matters  13-Jul-2021
# 3                             To consider Fund Raising  13-Jul-2021
# 4    To consider and approve the financial results ...  13-Jul-2021
# ..                                                 ...          ...
# 155  To consider and approve the financial results ...  12-Aug-2021
# 156  To consider and approve the financial results ...  12-Aug-2021
# 157  To consider and approve the financial results ...  13-Aug-2021
# 158  To consider and approve the financial results ...  13-Aug-2021
# 159  To consider and approve the financial results ...  14-Aug-2021
#
# [160 rows x 5 columns]

# %%
print(expiry_list('RELIANCE'))
# Out:
# INFO:root:Getting Expiry List of: RELIANCE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/option-chain-equities?symbol=RELIANCE HTTP/1.1" 401 272
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): nseindia.com:80
# DEBUG:urllib3.connectionpool:http://nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): www.nseindia.com:80
# DEBUG:urllib3.connectionpool:http://www.nseindia.com:80 "GET / HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 40540
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/option-chain-equities?symbol=RELIANCE HTTP/1.1" 200 15590
# None

# %%
def nse_optionchain_ltp(payload,strikePrice,optionType,inp=0,intent=""):
    expiryDate=payload['records']['expiryDates'][inp]
    for x in range(len(payload['records']['data'])):
      if((payload['records']['data'][x]['strikePrice']==strikePrice) & (payload['records']['data'][x]['expiryDate']==expiryDate)):
          if(intent==""): return payload['records']['data'][x][optionType]['lastPrice']
          if(intent=="sell"): return payload['records']['data'][x][optionType]['bidprice']
          if(intent=="buy"): return payload['records']['data'][x][optionType]['askPrice']

# %%
payload=nse_optionchain_scrapper('BANKNIFTY')
print(nse_optionchain_ltp(payload,23000,"CE",0,"sell"))
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/option-chain-indices?symbol=BANKNIFTY HTTP/1.1" 200 75228
# None
