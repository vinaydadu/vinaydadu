# %%
import pandas as pd

# %%
df = pd.read_csv('INvideos.csv')
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  10L1hZ9qa58      17.14.11
# 2  N1vE8iiEg64      17.14.11
# 3  kJzGH0PVQHQ      17.14.11
# 4  il_pSa5l98w      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           24  2017-11-12T15:48:08.000Z
# 2           23  2017-11-12T07:08:48.000Z
# 3           24  2017-11-13T01:14:16.000Z
# 4           24  2017-11-10T04:29:50.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  object
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  object
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %%
df['trending_date']
# Out:
# 0        17.14.11
# 1        17.14.11
# 2        17.14.11
# 3        17.14.11
# 4        17.14.11
#            ...
# 37346    18.14.06
# 37347    18.14.06
# 37348    18.14.06
# 37349    18.14.06
# 37350    18.14.06
# Name: trending_date, Length: 37351, dtype: object

# %%
## Convert trending_date to pandas date time format: Type cast

df['trending_date'] = pd.to_datetime(df['trending_date'], format = '%y.%d.%m')

# %%
df['trending_date']
# Out:
# 0       2017-11-14
# 1       2017-11-14
# 2       2017-11-14
# 3       2017-11-14
# 4       2017-11-14
#            ...
# 37346   2018-06-14
# 37347   2018-06-14
# 37348   2018-06-14
# 37349   2018-06-14
# 37350   2018-06-14
# Name: trending_date, Length: 37351, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  datetime64[ns]
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  object
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %%
df['publish_time']
# Out:
# 0        2017-11-12T12:20:39.000Z
# 1        2017-11-12T15:48:08.000Z
# 2        2017-11-12T07:08:48.000Z
# 3        2017-11-13T01:14:16.000Z
# 4        2017-11-10T04:29:50.000Z
#                    ...
# 37346    2018-06-13T08:01:11.000Z
# 37347    2018-06-13T11:30:04.000Z
# 37348    2018-06-13T05:00:02.000Z
# 37349    2018-06-13T15:07:49.000Z
# 37350    2018-06-10T04:29:54.000Z
# Name: publish_time, Length: 37351, dtype: object

# %%
df['publish_time'] = pd.to_datetime(df['publish_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  datetime64[ns]
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  datetime64[ns, UTC]
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  10L1hZ9qa58    2017-11-14
# 2  N1vE8iiEg64    2017-11-14
# 3  kJzGH0PVQHQ    2017-11-14
# 4  il_pSa5l98w    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id              publish_time  \
# 0            1 2017-11-12 12:20:39+00:00
# 1           24 2017-11-12 15:48:08+00:00
# 2           23 2017-11-12 07:08:48+00:00
# 3           24 2017-11-13 01:14:16+00:00
# 4           24 2017-11-10 04:29:50+00:00
#
#                                                 tags    views  likes  \
# ...

# %%
df['publish_date'] = df['publish_time'].dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  datetime64[ns]
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   publish_time            37351 non-null  datetime64[ns, UTC]
#  6   tags                    37351 non-null  object
#  7   views                   37351 non-null  int64
#  8   likes                   37351 non-null  int64
#  9   dislikes                37351 non-null  int64
#  10  comment_count           37351 non-null  int64
#  11  thumbnail_link          37351 non-null  object
#  12  comments_disabled       37351 non-null  bool
#  13  ratings_disabled        37351 non-null  bool
# ...

# %%
df['publish_date'] = pd.to_datetime(df['publish_time'].dt.date)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'publish_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-9645dd52421f> in <module>
# ...

# %% [markdown]
# lets drop a publish time column

# %%
#df.drop('publish_time, axis=1')#drop column
#df.drop(columns = ['publish_time'])#drop column using label
df.drop(columns = ['publish_time'], inplace=True) #drop column using label


#df.drop(2, axis=0)#drop row number
#df.drop(index = 0)#drop row using index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37351 entries, 0 to 37350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37351 non-null  object
#  1   trending_date           37351 non-null  datetime64[ns]
#  2   title                   37351 non-null  object
#  3   channel_title           37351 non-null  object
#  4   category_id             37351 non-null  int64
#  5   tags                    37351 non-null  object
#  6   views                   37351 non-null  int64
#  7   likes                   37351 non-null  int64
#  8   dislikes                37351 non-null  int64
#  9   comment_count           37351 non-null  int64
#  10  thumbnail_link          37351 non-null  object
#  11  comments_disabled       37351 non-null  bool
#  12  ratings_disabled        37351 non-null  bool
#  13  video_error_or_removed  37351 non-null  bool
# ...

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  10L1hZ9qa58    2017-11-14
# 2  N1vE8iiEg64    2017-11-14
# 3  kJzGH0PVQHQ    2017-11-14
# 4  il_pSa5l98w    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id                                               tags    views  \
# 0            1  sharry mann|"sharry mann new song"|"sharry man...  1096327
# 1           24  Stylish Star Allu Arjun @ ChaySam Wedding Rece...   473988
# 2           23  Eruma Saani|"Tamil Comedy Videos"|"Films"|"Mov...  1242680
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37346     True
# 37347     True
# 37348     True
# 37349     True
# 37350     True
# Length: 37351, dtype: bool

# %%
df.duplicated().value_counts()
# Out:
# False    33088
# True      4263
# dtype: int64

# %%
df.shape
# Out:
# (37351, 16)

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (33088, 16)

# %%
37351-33088
# Out:
# 4263

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  10L1hZ9qa58    2017-11-14
# 2  N1vE8iiEg64    2017-11-14
# 3  kJzGH0PVQHQ    2017-11-14
# 4  il_pSa5l98w    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id                                               tags    views  \
# 0            1  sharry mann|"sharry mann new song"|"sharry man...  1096327
# 1           24  Stylish Star Allu Arjun @ ChaySam Wedding Rece...   473988
# 2           23  Eruma Saani|"Tamil Comedy Videos"|"Films"|"Mov...  1242680
# ...

# %%
df.sort_values(by = 'views', ascending = False)
# Out:
#           video_id trending_date  \
# 5407   FlsCjmMhFmw    2017-12-12
# 5118   FlsCjmMhFmw    2017-12-11
# 4935   FlsCjmMhFmw    2017-12-10
# 4476   6ZfuNTqbHE8    2017-12-07
# 4235   6ZfuNTqbHE8    2017-12-06
# ...            ...           ...
# 5289   p3Wn9FuI2zo    2017-12-11
# 18319       #NAME?    2018-02-22
# 20322  18OSLOq-bFA    2018-03-06
# 29316  iW5ZRboFCMU    2018-05-01
# 29315  wntggWeDxjI    2018-05-01
#
#                                                    title  \
# 5407   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5118   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 4935   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 4476   Marvel Studios' Avengers: Infinity War Officia...
# 4235   Marvel Studios' Avengers: Infinity War Officia...
# ...                                                  ...
# 5289   Dilip Ghosh and Firhad Hakim's political fight...
# 18319  Madhuban Murli LIVE - 22/2/2018 (Thursday 7.00...
# ...

# %%
df['video_id'].value_counts()[:20]
# Out:
# #NAME?         442
# rRr1qiJRsXk     13
# EyPXz6hKa_s     11
# 1J76wN0TPI4     10
# Wm_vSSlVsV4     10
# aNwWdF8qq-M     10
# q8v9MvManKE      9
# FPm7xM849-E      9
# FCUPcNBpq4E      9
# J-dv_DcDD_A      9
# yFFL1we4j_Y      9
# iWZmdoY1aTE      9
# zMxIW7uwDGg      9
# bYSRPuDEnTg      9
# 4juJXyLX510      9
# u9Mv98Gr5pY      9
# g4HDfqEWf6Y      8
# sueMmTm-M4Y      8
# Tx0fhKJRaeU      8
# DMl1YJyqEdo      8
# Name: video_id, dtype: int64

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  10L1hZ9qa58    2017-11-14
# 2  N1vE8iiEg64    2017-11-14
# 3  kJzGH0PVQHQ    2017-11-14
# 4  il_pSa5l98w    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id                                               tags    views  \
# 0            1  sharry mann|"sharry mann new song"|"sharry man...  1096327
# 1           24  Stylish Star Allu Arjun @ ChaySam Wedding Rece...   473988
# 2           23  Eruma Saani|"Tamil Comedy Videos"|"Films"|"Mov...  1242680
# ...

# %% [markdown]
#    **Same Day trending**

# %%
same_day = df[df['publish_date'] == df['trending_date']]
same_day
# Out:
#           video_id trending_date  \
# 430    bvmlbu5Vipg    2017-11-16
# 2372   _r0mH98oPlg    2017-11-26
# 2902   j_Vlg4K05s8    2017-11-29
# 3680   Khg8JCK6PMI    2017-12-03
# 5332   wS7okEDsAWI    2017-12-12
# ...            ...           ...
# 36597  pq-eP_RCclI    2018-06-10
# 36715  fUoc7FMuwdY    2018-06-11
# 36722  8_ei7sQJ4FY    2018-06-11
# 36772  z7ddTuNukvQ    2018-06-11
# 36873  v9a6l_s2PKM    2018-06-12
#
#                                                    title  \
# 430    गुरुवार स्पेशल भजन : साईं बाबा रहमत की नज़र कर ...
# 2372   RAMAYANAM PART- 7 | Bahubali Ramayanam | Unkno...
# 2902   Dil De Kareeb | Garry Sandhu ( Full Video ) | ...
# 3680   RAMAYANAM PART - 10 | CLIMAX | Unknown Facts A...
# 5332   हनुमान चालीसा, Hanuman Chalisa Hari Om Sharan ...
# ...                                                  ...
# 36597             ఏసీల్లో కూర్చొని ఎవరైనా మాట్లాడుతారు..
# 36715  CET Common Eligibility test & Its Effect on st...
# ...

# %%
same_day.shape
# Out:
# (441, 16)

# %%
same_day.sort_values(by='views', ascending=False)
# Out:
#           video_id trending_date  \
# 35748  pnMQLrS5sTE    2018-06-06
# 36472  64UX1npgRkI    2018-06-10
# 16959  YBpdL9hSac4    2018-02-15
# 19356  i8J0cR-PY9c    2018-03-01
# 22734  rWmv4OzdHQw    2018-03-20
# ...            ...           ...
# 15144  dmYYpStfSeE    2018-02-04
# 17996  4fKgKl8W3ws    2018-02-20
# 18319       #NAME?    2018-02-22
# 20322  18OSLOq-bFA    2018-03-06
# 29316  iW5ZRboFCMU    2018-05-01
#
#                                                    title  \
# 35748  Guru Randhawa: MADE IN INDIA | Bhushan Kumar |...
# 36472  Sanju: Kar Har Maidaan Fateh | Ranbir Kapoor |...
# 16959                Incredibles 2 - Olympics Sneak Peek
# 19356  Baaghi 2: Mundiyan Song | Tiger Shroff, Disha ...
# 22734  WWE RAW 19th March 2018 - Brock Lesnar dismant...
# ...                                                  ...
# 15144    Ghadge & Suun - 3rd February 2018 - घाडगे & सून
# 17996  Madhuban Murli LIVE - 20/2/2018 (Tuesday 7.00a...
# ...

# %%
same_day[same_day['channel_title'] == 'T-Series'].sort_values(by= 'views', ascending = False)
# Out:
#           video_id trending_date  \
# 35748  pnMQLrS5sTE    2018-06-06
# 36472  64UX1npgRkI    2018-06-10
# 19356  i8J0cR-PY9c    2018-03-01
# 20032  z-ZEHL4Df-A    2018-03-05
#
#                                                    title channel_title  \
# 35748  Guru Randhawa: MADE IN INDIA | Bhushan Kumar |...      T-Series
# 36472  Sanju: Kar Har Maidaan Fateh | Ranbir Kapoor |...      T-Series
# 19356  Baaghi 2: Mundiyan Song | Tiger Shroff, Disha ...      T-Series
# 20032  Patola Video Song | Blackmail | Irrfan Khan & ...      T-Series
#
#        category_id                                               tags  \
# 35748           10  made in india guru randhawa|"made in india son...
# 36472           10  Kar Har Maidaan Fateh|"kar har maidan fateh"|"...
# 19356           10  Mundiyan To Bach Ke Rahi|"ke"|"bach"|"Mundiyan...
# 20032           10  blackmail songs|"blackmovie songs"|"patola son...
#
#          views   likes  dislikes  comment_count  \
# ...

# %%
same_day['channel_title'].value_counts().head(5)
# Out:
# Adda247 :Official Channel of BankersAdda & SSCAdda    48
# WiFiStudy                                             28
# Mahendra Guru : Online Videos For Govt. Exams         16
# Study IQ education                                    12
# T-Series Bhakti Sagar                                 11
# Name: channel_title, dtype: int64

# %%
same_day.groupby("channel_title").agg({'video_id':'count','views':'sum'}).sort_values("views", ascending=False).head()
# Out:
#                   video_id     views
# channel_title
# T-Series                 4  13205923
# WWE                      6   5308127
# Wrestling Phobia         2   3670140
# Speed Records            4   2221143
# Disney•Pixar             1   1948452

# %%
df.sort_values(by='views', ascending=False)
# Out:
#           video_id trending_date  \
# 5407   FlsCjmMhFmw    2017-12-12
# 5118   FlsCjmMhFmw    2017-12-11
# 4935   FlsCjmMhFmw    2017-12-10
# 4476   6ZfuNTqbHE8    2017-12-07
# 4235   6ZfuNTqbHE8    2017-12-06
# ...            ...           ...
# 5289   p3Wn9FuI2zo    2017-12-11
# 18319       #NAME?    2018-02-22
# 20322  18OSLOq-bFA    2018-03-06
# 29316  iW5ZRboFCMU    2018-05-01
# 29315  wntggWeDxjI    2018-05-01
#
#                                                    title  \
# 5407   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5118   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 4935   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 4476   Marvel Studios' Avengers: Infinity War Officia...
# 4235   Marvel Studios' Avengers: Infinity War Officia...
# ...                                                  ...
# 5289   Dilip Ghosh and Firhad Hakim's political fight...
# 18319  Madhuban Murli LIVE - 22/2/2018 (Thursday 7.00...
# ...

# %%
df1 = df.drop_duplicates(subset = 'video_id', keep = 'last').sort_values(by='views', ascending=False)

# %%
df1.shape
# Out:
# (16307, 16)

# %%
tseries = df1[df['channel_title']=='T-Series']
# Out:
# <ipython-input-79-f40f500f82cc>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tseries = df1[df['channel_title']=='T-Series']

# %%
tseries.shape
# Out:
# (62, 16)

# %%
tseries.head()
# Out:
#           video_id trending_date  \
# 9379   xWi8nDUjHGA    2018-01-02
# 23311  q2gICJFG6uw    2018-03-24
# 29663  aNwWdF8qq-M    2018-05-03
# 6911   dZ0fwJojhrs    2017-12-20
# 21738  Qvd43XKY-f0    2018-03-15
#
#                                                    title channel_title  \
# 9379   Yo Yo Honey Singh: DIL CHORI (Video) Simar Kau...      T-Series
# 23311  Baaghi 2: Ek Do Teen Song | Jacqueline Fernand...      T-Series
# 29663  Official Video: Raat Kamaal Hai | Guru Randhaw...      T-Series
# 6911   Guru Randhawa: Lahore (Official Video) Bhushan...      T-Series
# 21738  Baaghi 2 : O Saathi Video Song | Tiger Shroff ...      T-Series
#
#        category_id                                               tags  \
# 9379            10  latest hindi songs|"bollywood"|"songs"|"2017"|...
# 23311           10  ek do teen|"ek do teen baaghi 2"|"baaghi 2 son...
# 29663           10  latest hindi songs|"bollywood songs"|"songs"|"...
# ...

# %%
tseries.datetimeindex('publish_date'.)

# %%
tseries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 9379 to 5055
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                62 non-null     object
#  1   trending_date           62 non-null     datetime64[ns]
#  2   title                   62 non-null     object
#  3   channel_title           62 non-null     object
#  4   category_id             62 non-null     int64
#  5   tags                    62 non-null     object
#  6   views                   62 non-null     int64
#  7   likes                   62 non-null     int64
#  8   dislikes                62 non-null     int64
#  9   comment_count           62 non-null     int64
#  10  thumbnail_link          62 non-null     object
#  11  comments_disabled       62 non-null     bool
#  12  ratings_disabled        62 non-null     bool
#  13  video_error_or_removed  62 non-null     bool
# ...

# %%
tseries['publish_date'] = pd.to_datetime(df['publish_date'])
# Out:
# <ipython-input-92-2b2413ca0eca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tseries['publish_date'] = pd.to_datetime(df['publish_date'])

# %%
tseries['month'] = tseries.publish_date.dt.month
# Out:
# <ipython-input-93-c3717ce00e0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tseries['month'] = tseries.publish_date.dt.month

# %%
tseries.head()
# Out:
#           video_id trending_date  \
# 9379   xWi8nDUjHGA    2018-01-02
# 23311  q2gICJFG6uw    2018-03-24
# 29663  aNwWdF8qq-M    2018-05-03
# 6911   dZ0fwJojhrs    2017-12-20
# 21738  Qvd43XKY-f0    2018-03-15
#
#                                                    title channel_title  \
# 9379   Yo Yo Honey Singh: DIL CHORI (Video) Simar Kau...      T-Series
# 23311  Baaghi 2: Ek Do Teen Song | Jacqueline Fernand...      T-Series
# 29663  Official Video: Raat Kamaal Hai | Guru Randhaw...      T-Series
# 6911   Guru Randhawa: Lahore (Official Video) Bhushan...      T-Series
# 21738  Baaghi 2 : O Saathi Video Song | Tiger Shroff ...      T-Series
#
#        category_id                                               tags  \
# 9379            10  latest hindi songs|"bollywood"|"songs"|"2017"|...
# 23311           10  ek do teen|"ek do teen baaghi 2"|"baaghi 2 son...
# 29663           10  latest hindi songs|"bollywood songs"|"songs"|"...
# ...

# %%
tseries.month.value_counts(normalize=True).sort_index(ascending = False)
# Out:
# 12    0.145161
# 11    0.080645
# 6     0.064516
# 5     0.129032
# 4     0.096774
# 3     0.161290
# 2     0.177419
# 1     0.145161
# Name: month, dtype: float64
