# %%
pip install --upgrade mplfinance
# Out:
# Collecting mplfinance
#   Downloading mplfinance-0.12.7a17-py3-none-any.whl (62 kB)
# Requirement already satisfied, skipping upgrade: matplotlib in c:\programdata\anaconda3\lib\site-packages (from mplfinance) (3.3.2)
# Requirement already satisfied, skipping upgrade: pandas in c:\programdata\anaconda3\lib\site-packages (from mplfinance) (1.1.3)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2020.6.20)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.3.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.8.1)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mplfinance) (8.0.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mplfinance) (0.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mplfinance) (1.19.2)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mplfinance) (2.4.7)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->mplfinance) (2020.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.1->matplotlib->mplfinance) (1.15.0)
# Installing collected packages: mplfinance
# Successfully installed mplfinance-0.12.7a17
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime
import datetime as dt
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import yfinance as yf
from matplotlib.dates import DateFormatter, WeekdayLocator,\
    DayLocator, MONDAY
from mpl_finance import candlestick_ohlc
import warnings
from matplotlib.dates import date2num

# %%
pd.set_option('display.max_rows', None)
tickers_df=pd.read_csv(r'C:\Users\LENOVO\Downloads\fo_mktlots (1).csv',skiprows=4)

# %%
datamaster_df=pd.DataFrame()

i=0
while i<len(tickers_df):
    ticker = tickers_df['Symbol'][i]+'.NS'
    eq_df = yf.download(ticker,'2020-04-01','2021-05-29')
    eq_df.reset_index(inplace=True)
    eq_df=eq_df.dropna()
    datamaster_df=datamaster_df.append(eq_df)
    i+=1
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tickers_df
tickers_df.sort_values(by = 'Symbol')
# Out:
#      Derivatives on Individual Securities      Symbol  Feb-21  Mar-21  Apr-21  \
# 0    AARTI INDUSTRIES LTD                    AARTIIND     425     425     425
# 32   ACC LIMITED                                  ACC     500     500     500
# 1    ADANI ENTERPRISES LIMITED               ADANIENT    2000    2000    2000
# 2    ADANI PORT & SEZ LTD                  ADANIPORTS    2500    2500    2500
# 3    AMARA RAJA BATTERIES LTD.             AMARAJABAT    1000    1000    1000
# 83   AMBUJA CEMENTS LTD                     AMBUJACEM    3000    3000    3000
# 6    APOLLO HOSPITALS ENTER. L             APOLLOHOSP     500     500     500
# 4    APOLLO TYRES LTD                      APOLLOTYRE    5000    5000    5000
# 5    ASHOK LEYLAND LTD                       ASHOKLEY    9000    9000    9000
# 7    ASIAN PAINTS LIMITED                  ASIANPAINT     300     300     300
# 8    AUROBINDO PHARMA LTD                  AUROPHARMA     650     650     650
# 12   AXIS BANK LIMITED                       AXISBANK    1200    1200    1200
# 9    BAJAJ AUTO LIMITED                    BAJAJ-AUTO     250     250     250
# 125  BAJAJ FINSERV LTD.                    BAJAJFINSV     125     125     125
# 17   BAJAJ FINANCE LIMITED                 BAJFINANCE     250     250     250
# 18   BALKRISHNA IND. LTD                   BALKRISIND     400     400     400
# 118  BANDHAN BANK LIMITED                  BANDHANBNK    1800    1800    1800
# 10   BANK OF BARODA                        BANKBARODA   11700   11700   11700
# 24   BATA INDIA LTD                         BATAINDIA     550     550     550
# 11   BHARAT ELECTRONICS LTD                       BEL    7600    7600    7600
# 13   BERGER PAINTS (I) LTD                 BERGEPAINT    1100    1100    1100
# 86   BHARAT FORGE LTD                      BHARATFORG    1500    1500    1500
# 26   BHARTI AIRTEL LIMITED                 BHARTIARTL    1851    1851    1851
# 14   BHEL                                        BHEL   21000   21000   21000
# 120  BIOCON LIMITED.                           BIOCON    2300    2300    2300
# 126  BOSCH LIMITED                           BOSCHLTD      50      50      50
# 28   BHARAT PETROLEUM CORP  LT                   BPCL    1800    1800    1800
# 30   BRITANNIA INDUSTRIES LTD               BRITANNIA     200     200     200
# 15   CADILA HEALTHCARE LIMITED               CADILAHC    2200    2200    2200
# 16   CANARA BANK                                CANBK    5400    5400    5400
# 19   CHOLAMANDALAM IN & FIN CO               CHOLAFIN    2500    2500    2500
# 20   CIPLA LTD                                  CIPLA    1300    1300    1300
# 92   COAL INDIA LTD                         COALINDIA    4200    4200    4200
# 39   COFORGE LIMITED                          COFORGE     375     375     375
# 127  COLGATE PALMOLIVE LTD.                    COLPAL     700     700     700
# 21   CONTAINER CORP OF IND LTD                 CONCOR    1563    1563    1563
# 22   CUMMINS INDIA LTD                     CUMMINSIND    1200    1200    1200
# 101  DABUR INDIA LTD                            DABUR    1250    1250    1250
# 46   DIVI'S LABORATORIES LTD                 DIVISLAB     200     200     200
# 23   DLF LIMITED                                  DLF    3300    3300    3300
# 25   DR. REDDY'S LABORATORIES                 DRREDDY     125     125     125
# 103  EICHER MOTORS LTD                      EICHERMOT     350     350     350
# 47   ESCORTS INDIA LTD                        ESCORTS     550     550     550
# 54   EXIDE INDUSTRIES LTD                    EXIDEIND    3600    3600    3600
# 27   FEDERAL BANK LTD                      FEDERALBNK   10000   10000   10000
# 108  GAIL (INDIA) LTD                            GAIL    6100    6100    6100
# 128  GLENMARK PHARMACEUTICALS                GLENMARK    1150    1150    1150
# 60   GMR INFRASTRUCTURE LTD.                 GMRINFRA   22500   22500   22500
# 110  GODREJ CONSUMER PRODUCTS                GODREJCP    1000    1000    1000
# 62   GODREJ PROPERTIES LTD                 GODREJPROP     650     650     650
# 114  GRASIM INDUSTRIES LTD                     GRASIM     950     950     950
# 129  HAVELLS INDIA LIMITED                    HAVELLS    1000    1000    1000
# 64   HCL TECHNOLOGIES LTD                     HCLTECH     700     700     700
# 121  HDFC LTD                                    HDFC     300     300     300
# 29   HDFC AMC LIMITED                         HDFCAMC     200     200     200
# 31   HDFC BANK LTD                           HDFCBANK     550     550     550
# 70   HDFC LIFE INS CO LTD                    HDFCLIFE    1100    1100    1100
# 71   HERO MOTOCORP LIMITED                 HEROMOTOCO     300     300     300
# 72   HINDALCO  INDUSTRIES  LTD               HINDALCO    4300    4300    4300
# 73   HINDUSTAN PETROLEUM CORP               HINDPETRO    2700    2700    2700
# 74   HINDUSTAN UNILEVER LTD.               HINDUNILVR     300     300     300
# 130  INDIABULLS HSG FIN LTD                IBULHSGFIN    3100    3100    3100
# 75   ICICI BANK LTD.                        ICICIBANK    1375    1375    1375
# 122  ICICI LOMBARD GIC LIMITED                ICICIGI     425     425     425
# 77   ICICI PRU LIFE INS CO LTD             ICICIPRULI    1500    1500    1500
# 123  VODAFONE IDEA LIMITED                       IDEA   70000   70000   70000
# 78   IDFC FIRST BANK LIMITED               IDFCFIRSTB   19000   19000   19000
# 33   INDRAPRASTHA GAS LTD                         IGL    1375    1375    1375
# 79   INTERGLOBE AVIATION LTD                   INDIGO     500     500     500
# 131  INDUSIND BANK LIMITED                 INDUSINDBK     900     900     900
# 124  INDUS TOWERS LIMITED                  INDUSTOWER    2800    2800    2800
# 80   INFOSYS LIMITED                             INFY     600     600     600
# 81   INDIAN OIL CORP LTD                          IOC    6500    6500    6500
# 34   ITC LTD                                      ITC    3200    3200    3200
# 35   JINDAL STEEL & POWER LTD              JINDALSTEL    5000    5000    5000
# 36   JSW STEEL LIMITED                       JSWSTEEL    2700    2700    2700
# 138  JUBILANT FOODWORKS LTD                  JUBLFOOD     250     250     250
# 82   KOTAK MAHINDRA BANK LTD                KOTAKBANK     400     400     400
# 37   L&T FINANCE HOLDINGS LTD                   L&TFH    8924    8924    8924
# 38   DR. LAL PATH LABS LTD.                LALPATHLAB     250     250     250
# 40   LIC HOUSING FINANCE LTD                LICHSGFIN    2000    2000    2000
# 41   LARSEN & TOUBRO LTD.                          LT     575     575     575
# 42   LUPIN LIMITED                              LUPIN     850     850     850
# 43   MAHINDRA & MAHINDRA LTD                      M&M    1400    1400    1400
# 44   M&M FIN. SERVICES LTD                     M&MFIN    4000    4000    4000
# 45   MANAPPURAM FINANCE LTD                MANAPPURAM    6000    6000    6000
# 84   MARICO LIMITED                            MARICO    2000    2000    2000
# 48   MARUTI SUZUKI INDIA LTD.                  MARUTI     100     100     100
# 85   UNITED SPIRITS LIMITED                MCDOWELL-N    1250    1250    1250
# 49   MAX FINANCIAL SERV LTD                      MFSL    1300    1300    1300
# 87   MAHANAGAR GAS LTD.                           MGL     600     600     600
# 88   MINDTREE LIMITED                        MINDTREE     800     800     800
# 89   MOTHERSON SUMI SYSTEMS LT             MOTHERSUMI    7000    7000    7000
# 90   MRF LTD                                      MRF      10      10      10
# 91   MUTHOOT FINANCE LIMITED               MUTHOOTFIN     750     750     750
# 50   NATIONAL ALUMINIUM CO LTD             NATIONALUM   17000   17000   17000
# 93   INFO EDGE (I) LTD                         NAUKRI     250     250     250
# 94   NESTLE INDIA LIMITED                   NESTLEIND      50      50      50
# 51   NMDC LTD.                                   NMDC    6700    6700    6700
# 95   NTPC LTD                                    NTPC    5700    5700    5700
# 96   OIL AND NATURAL GAS CORP.                   ONGC    7700    7700    7700
# 52   PAGE INDUSTRIES LTD                      PAGEIND      30      30      30
# 53   PIRAMAL ENTERPRISES LTD                      PEL     550     550     550
# 97   PETRONET LNG LIMITED                    PETRONET    3000    3000    3000
# 98   POWER FIN CORP LTD.                          PFC    6200    6200    6200
# 55   PIDILITE INDUSTRIES LTD               PIDILITIND     500     500     500
# 99   PUNJAB NATIONAL BANK                         PNB   16000   16000   16000
# 100  POWER GRID CORP. LTD.                  POWERGRID    4000    4000    4000
# 56   PVR LIMITED                                  PVR     407     407     407
# 102  THE RAMCO CEMENTS LIMITED               RAMCOCEM     850     850     850
# 104  RBL BANK LIMITED                         RBLBANK    2900    2900    2900
# 132  REC LIMITED                               RECLTD    6000    6000    6000
# 139  RELIANCE INDUSTRIES LTD                 RELIANCE     250     250     250
# 57   STEEL AUTHORITY OF INDIA                    SAIL   19000   19000   19000
# 105  SBI LIFE INSURANCE CO LTD                SBILIFE     750     750     750
# 58   STATE BANK OF INDIA                         SBIN    3000    3000    3000
# 133  SHREE CEMENT LIMITED                    SHREECEM      50      50      50
# 59   SIEMENS LTD                              SIEMENS     550     550     550
# 61   SRF LTD                                      SRF     125     125     125
# 63   SHRIRAM TRANSPORT FIN CO.             SRTRANSFIN     800     800     800
# 65   SUN PHARMACEUTICAL IND L               SUNPHARMA    1400    1400    1400
# 106  SUN TV NETWORK LIMITED                     SUNTV    1500    1500    1500
# 107  TATA CHEMICALS LTD                      TATACHEM    2000    2000    2000
# 66   TATA CONSUMER PRODUCT LTD             TATACONSUM    1350    1350    1350
# 109  TATA MOTORS LIMITED                   TATAMOTORS    5700    5700    5700
# 67   TATA POWER CO LTD                      TATAPOWER   13500   13500   13500
# 111  TATA STEEL LIMITED                     TATASTEEL    1700    1700    1700
# 68   TATA CONSULTANCY SERV LT                     TCS     300     300     300
# 69   TECH MAHINDRA LIMITED                      TECHM    1200    1200    1200
# 112  TITAN COMPANY LIMITED                      TITAN     750     750     750
# 135  TORRENT PHARMACEUTICALS L             TORNTPHARM     250     250     250
# 113  TORRENT POWER LTD                     TORNTPOWER    3000    3000    3000
# 115  TVS MOTOR COMPANY  LTD                  TVSMOTOR    1400    1400    1400
# 136  UNITED BREWERIES LTD                         UBL     700     700     700
# 116  ULTRATECH CEMENT LIMITED              ULTRACEMCO     200     200     200
# 137  UPL LIMITED                                  UPL    1300    1300    1300
# 134  VEDANTA LIMITED                             VEDL    6200    6200    6200
# 117  VOLTAS LTD                                VOLTAS    1000    1000    1000
# 76   WIPRO LTD                                  WIPRO    3200    3200    3200
# 119  ZEE ENTERTAINMENT ENT LTD                   ZEEL    3000    3000    3000
#
#                             .1            .2            .3            .4  \
# 0
# 32
# 1
# 2
# 3
# 83
# 6
# 4
# 5
# 7
# 8
# 12
# 9
# 125
# 17
# 18
# 118
# 10
# 24
# 11
# 13
# 86
# 26
# 14
# 120
# 126
# 28
# 30
# 15
# 16
# 19
# 20
# 92
# 39
# 127
# 21
# 22
# 101
# 46
# 23
# 25
# 103
# 47
# 54
# 27
# 108
# 128
# 60
# 110
# 62
# 114
# 129
# 64
# 121
# 29
# 31
# 70
# 71
# 72
# 73
# 74
# 130
# 75
# 122
# 77
# 123
# 78
# 33
# 79
# 131
# 124
# 80
# 81
# 34
# 35
# 36
# 138
# 82
# 37
# 38
# 40
# 41
# 42
# 43
# 44
# 45
# 84
# 48
# 85
# 49
# 87
# 88
# 89
# 90
# 91
# 50
# 93
# 94
# 51
# 95
# 96
# 52
# 53
# 97
# 98
# 55
# 99
# 100
# 56
# 102
# 104
# 132
# 139
# 57
# 105
# 58
# 133
# 59
# 61
# 63
# 65
# 106
# 107
# 66
# 109
# 67
# 111
# 68
# 69
# 112
# 135
# 113
# 115
# 136
# 116
# 137
# 134
# 117
# 76
# 119
#
#                .5            .6            .7            .8            .9  \
# 0
# 32
# 1
# 2
# 3
# 83
# 6
# 4
# 5
# 7
# 8
# 12
# 9
# 125
# 17
# 18
# 118
# 10
# 24
# 11
# 13
# 86
# 26
# 14
# 120
# 126
# 28
# 30
# 15
# 16
# 19
# 20
# 92
# 39
# 127
# 21
# 22
# 101
# 46
# 23
# 25
# 103
# 47
# 54
# 27
# 108
# 128
# 60
# 110
# 62
# 114
# 129
# 64
# 121
# 29
# 31
# 70
# 71
# 72
# 73
# 74
# 130
# 75
# 122
# 77
# 123
# 78
# 33
# 79
# 131
# 124
# 80
# 81
# 34
# 35
# 36
# 138
# 82
# 37
# 38
# 40
# 41
# 42
# 43
# 44
# 45
# 84
# 48
# 85
# 49
# 87
# 88
# 89
# 90
# 91
# 50
# 93
# 94
# 51
# 95
# 96
# 52
# 53
# 97
# 98
# 55
# 99
# 100
# 56
# 102
# 104
# 132
# 139
# 57
# 105
# 58
# 133
# 59
# 61
# 63
# 65
# 106
# 107
# 66
# 109
# 67
# 111
# 68
# 69
# 112
# 135
# 113
# 115
# 136
# 116
# 137
# 134
# 117
# 76
# 119
#
#                .10
# 0
# 32
# 1
# 2
# 3
# 83
# 6
# 4
# 5
# 7
# 8
# 12
# 9
# 125
# 17
# 18
# 118
# 10
# 24
# 11
# 13
# 86
# 26
# 14
# 120
# 126
# 28
# 30
# 15
# 16
# 19
# 20
# 92
# 39
# 127
# 21
# 22
# 101
# 46
# 23
# 25
# 103
# 47
# 54
# 27
# 108
# 128
# 60
# 110
# 62
# 114
# 129
# 64
# 121
# 29
# 31
# 70
# 71
# 72
# 73
# 74
# 130
# 75
# 122
# 77
# 123
# 78
# 33
# 79
# 131
# 124
# 80
# 81
# 34
# 35
# 36
# 138
# 82
# 37
# 38
# 40
# 41
# 42
# 43
# 44
# 45
# 84
# 48
# 85
# 49
# 87
# 88
# 89
# 90
# 91
# 50
# 93
# 94
# 51
# 95
# 96
# 52
# 53
# 97
# 98
# 55
# 99
# 100
# 56
# 102
# 104
# 132
# 139
# 57
# 105
# 58
# 133
# 59
# 61
# 63
# 65
# 106
# 107
# 66
# 109
# 67
# 111
# 68
# 69
# 112
# 135
# 113
# 115
# 136
# 116
# 137
# 134
# 117
# 76
# 119

# %%
for i in range(2,df.shape[0]):
  current = df.iloc[i,:]
  prev = df.iloc[i-1,:]
  prev_2 = df.iloc[i-2,:]
realbody = abs(current['Open'] - current['Close'])
  candle_range = current['High'] - current['Low']
idx = df.index[i]
  
  # Bullish swing
  df.loc[idx,'Bullish swing'] = current['Low'] > prev['Low'] and prev['Low'] < prev_2['Low']
# Bearish swing
  df.loc[idx,'Bearish swing'] = current['High'] < prev['High'] and prev['High'] > prev_2['High']
# Bullish pinbar
  df.loc[idx,'Bullish pinbar'] = realbody <= candle_range/3 and  min(current['Open'], current['Close']) > (current['High'] + current['Low'])/2 and current['Low'] < prev['Low']
# Bearish pinbar
  df.loc[idx,'Bearish pinbar'] = realbody <= candle_range/3 and max(current['Open'] , current['Close']) < (current['High'] + current['Low'])/2 and current['High'] > prev['High']
    
  # Inside bar
  df.loc[idx,'Inside bar'] = current['High'] < prev['High'] and current['Low'] > prev['Low']
    
  # Outside bar
  df.loc[idx,'Outside bar'] = current['High'] > prev['High'] and current['Low'] < prev['Low']
  
  # Bullish engulfing
  df.loc[idx,'Bullish engulfing'] = current['High'] > prev['High'] and current['Low'] < prev['Low'] and realbody >= 0.8 * candle_range and current['Close'] > current['Open']
# Bearish engulfing
  df.loc[idx,'Bearish engulfing'] = current['High'] > prev['High'] and current['Low'] < prev['Low'] and realbody >= 0.8 * candle_range and current['Close'] < current['Open']
df.fillna(False, inplace=True)

# %%
def pandas_candlestick_ohlc(dat, stick = "day", adj = False, otherseries = None):
    """
    :param dat: pandas DataFrame object with datetime64 index, and float columns "Open", "High", "Low", and "Close", likely created via DataReader from "yahoo"
    :param stick: A string or number indicating the period of time covered by a single candlestick. Valid string inputs include "day", "week", "month", and "year", ("day" default), and any numeric input indicates the number of trading days included in a period
    :param adj: A boolean indicating whether to use adjusted prices
    :param otherseries: An iterable that will be coerced into a list, containing the columns of dat that hold other series to be plotted as lines
 
    This will show a Japanese candlestick plot for stock data stored in dat, also plotting other series if passed.
    """
    mondays = WeekdayLocator(MONDAY)        # major ticks on the mondays
    alldays = DayLocator()              # minor ticks on the days
    dayFormatter = DateFormatter('%d')      # e.g., 12
 
    # Create a new DataFrame which includes OHLC data for each period specified by stick input
    fields = ["Open", "High", "Low", "Close"]
    if adj:
        fields = [s for s in fields]
    transdat = dat.loc[:,fields]
    transdat.columns = pd.Index(["Open", "High", "Low", "Close"])
    if (type(stick) == str):
        if stick == "day":
            plotdat = transdat
            stick = 1 # Used for plotting
        elif stick in ["week", "month", "year"]:
            if stick == "week":
                transdat["week"] = pd.to_datetime(transdat.index).map(lambda x: x.isocalendar()[1]) # Identify weeks
            elif stick == "month":
                transdat["month"] = pd.to_datetime(transdat.index).map(lambda x: x.month) # Identify months
            transdat["year"] = pd.to_datetime(transdat.index).map(lambda x: x.isocalendar()[0]) # Identify years
            grouped = transdat.groupby(list(set(["year",stick]))) # Group by year and other appropriate variable
            plotdat = pd.DataFrame({"Open": [], "High": [], "Low": [], "Close": []}) # Create empty data frame containing what will be plotted
            for name, group in grouped:
                plotdat = plotdat.append(pd.DataFrame({"Open": group.iloc[0,0],
                                            "High": max(group.High),
                                            "Low": min(group.Low),
                                            "Close": group.iloc[-1,3]},
                                           index = [group.index[0]]))
            if stick == "week": stick = 5
            elif stick == "month": stick = 30
            elif stick == "year": stick = 365
 
    elif (type(stick) == int and stick >= 1):
        transdat["stick"] = [np.floor(i / stick) for i in range(len(transdat.index))]
        grouped = transdat.groupby("stick")
        plotdat = pd.DataFrame({"Open": [], "High": [], "Low": [], "Close": []}) # Create empty data frame containing what will be plotted
        for name, group in grouped:
            plotdat = plotdat.append(pd.DataFrame({"Open": group.iloc[0,0],
                                        "High": max(group.High),
                                        "Low": min(group.Low),
                                        "Close": group.iloc[-1,3]},
                                       index = [group.index[0]]))
 
    else:
        raise ValueError('Valid inputs to argument "stick" include the strings "day", "week", "month", "year", or a positive integer')
 
 
    # Set plot parameters, including the axis object ax used for plotting
    fig, ax = plt.subplots()
    fig.subplots_adjust(bottom=0.2)
    if plotdat.index[-1] - plotdat.index[0] == pd.Timedelta('730 days'):
        weekFormatter = DateFormatter('%b %d')  # e.g., Jan 12
        ax.xaxis.set_major_locator(mondays)
        ax.xaxis.set_minor_locator(alldays)
    else:
        weekFormatter = DateFormatter('%b %d, %Y')
    ax.xaxis.set_major_formatter(weekFormatter)
 
    ax.grid(True)
 
    # Create the candelstick chart
    candlestick_ohlc(ax, list(zip(list(date2num(plotdat.index.tolist())), plotdat["Open"].tolist(), plotdat["High"].tolist(),
                      plotdat["Low"].tolist(), plotdat["Close"].tolist())),
                      colorup = "black", colordown = "red", width = stick * .4)
 
    # Plot other series (such as moving averages) as lines
    if otherseries != None:
        if type(otherseries) != list:
            otherseries = [otherseries]
        dat.loc[:,otherseries].plot(ax = ax, lw = 1.3, grid = True)
 
    ax.xaxis_date()
    ax.autoscale_view()
    plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
 
    plt.show()
 
pandas_candlestick_ohlc(datamaster_df, adj=True, stick="month")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-5e7579ebc851> in <module>
#      85     plt.show()
#      86
# ---> 87 pandas_candlestick_ohlc(datamaster_df, adj=True, stick="month")
#
# <ipython-input-11-5e7579ebc851> in pandas_candlestick_ohlc(dat, stick, adj, otherseries)
#      69
#      70     # Create the candelstick chart
# ---> 71     candlestick_ohlc(ax, list(zip(list(date2num(plotdat.index.tolist())), plotdat["Open"].tolist(), plotdat["High"].tolist(),
#      72                       plotdat["Low"].tolist(), plotdat["Close"].tolist())),
#      73                       colorup = "black", colordown = "red", width = stick * .4)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\dates.py in date2num(d)
#     442         if not d.size:
#     443             return d
# --> 444         return _to_ordinalf_np_vectorized(d)
#     445
#     446
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2106             vargs.extend([kwargs[_n] for _n in names])
#    2107
# -> 2108         return self._vectorize_call(func=func, args=vargs)
#    2109
#    2110     def _get_ufunc_and_otypes(self, func, args):
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2184             res = func()
#    2185         else:
# -> 2186             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2187
#    2188             # Convert args to object arrays first
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2144
#    2145             inputs = [arg.flat[0] for arg in args]
# -> 2146             outputs = func(*inputs)
#    2147
#    2148             # Performance note: profiling indicates that -- for simple
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\dates.py in _to_ordinalf(dt)
#     297         dt = dt.astimezone(UTC)
#     298         dt = dt.replace(tzinfo=None)
# --> 299     dt64 = np.datetime64(dt)
#     300     return _dt64_to_ordinalf(dt64)
#     301
#
# ValueError: Could not convert object to NumPy datetime
